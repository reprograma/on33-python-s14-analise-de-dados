# %%
import pandas as pd

# %%
df_netflix = pd.read_csv(r"C:\Users\brend\OneDrive\Documentos\PYTHON\REPROGRAMA\Semana 14\on33-python-s14-analise-de-dados\material\dados\netflix.csv")
df_netflix.head(10)
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
# 5        6           Premium               15  18-03-22          27-06-23
# 6        7          Standard               12  09-12-21          25-06-23
# 7        8             Basic               10  02-04-23          24-06-23
# 8        9          Standard               12  20-10-22          23-06-23
# 9       10           Premium               15  07-01-23          22-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month
# 5          France   29  Female    Smart TV       1 Month
# 6          Brazil   46    Male      Tablet       1 Month
# 7          Mexico   39  Female      Laptop       1 Month
# 8           Spain   37    Male  Smartphone       1 Month
# 9           Italy   44  Female    Smart TV       1 Month

# %%
df_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %%
df_netflix.isna().sum()
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %%
df_netflix.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_netflix['Join Date'] = pd.to_datetime(df_netflix['Join Date'], format = "%d-%m-%y")
df_netflix['Last Payment Date'] = pd.to_datetime(df_netflix['Last Payment Date'], format = "%d-%m-%y")

# %%
print(df_netflix.dtypes)
# Out:
# User ID                       int64
# Subscription Type            object
# Monthly Revenue               int64
# Join Date            datetime64[ns]
# Last Payment Date    datetime64[ns]
# Country                      object
# Age                           int64
# Gender                       object
# Device                       object
# Plan Duration                object
# dtype: object

# %%
df_netflix.describe()
# Out:
#           User ID  Monthly Revenue                   Join Date  \
# count  2500.00000      2500.000000                        2500
# mean   1250.50000        12.508400  2022-08-28 18:02:52.800000
# min       1.00000        10.000000         2021-09-05 00:00:00
# 25%     625.75000        11.000000         2022-07-15 00:00:00
# 50%    1250.50000        12.000000         2022-08-31 00:00:00
# 75%    1875.25000        14.000000         2022-10-17 00:00:00
# max    2500.00000        15.000000         2023-06-14 00:00:00
# std     721.83216         1.686851                         NaN
#
#                 Last Payment Date          Age
# count                        2500  2500.000000
# mean   2023-07-03 08:54:31.680000    38.795600
# min           2023-06-10 00:00:00    26.000000
# 25%           2023-06-29 00:00:00    32.000000
# 50%           2023-07-03 00:00:00    39.000000
# 75%           2023-07-08 00:00:00    45.000000
# max           2023-07-15 00:00:00    51.000000
# std                           NaN     7.171778

# %%
df_netflix["Country"].nunique()
# Out:
# 10

# %%
df_netflix['Country'].unique()
# Out:
# array(['United States', 'Canada', 'United Kingdom', 'Australia',
#        'Germany', 'France', 'Brazil', 'Mexico', 'Spain', 'Italy'],
#       dtype=object)

# %%
df_netflix.describe(include='all')
# Out:
#            User ID Subscription Type  Monthly Revenue  \
# count   2500.00000              2500      2500.000000
# unique         NaN                 3              NaN
# top            NaN             Basic              NaN
# freq           NaN               999              NaN
# mean    1250.50000               NaN        12.508400
# min        1.00000               NaN        10.000000
# 25%      625.75000               NaN        11.000000
# 50%     1250.50000               NaN        12.000000
# 75%     1875.25000               NaN        14.000000
# max     2500.00000               NaN        15.000000
# std      721.83216               NaN         1.686851
#
#                          Join Date           Last Payment Date        Country  \
# count                         2500                        2500           2500
# unique                         NaN                         NaN             10
# top                            NaN                         NaN  United States
# freq                           NaN                         NaN            451
# mean    2022-08-28 18:02:52.800000  2023-07-03 08:54:31.680000            NaN
# min            2021-09-05 00:00:00         2023-06-10 00:00:00            NaN
# 25%            2022-07-15 00:00:00         2023-06-29 00:00:00            NaN
# 50%            2022-08-31 00:00:00         2023-07-03 00:00:00            NaN
# 75%            2022-10-17 00:00:00         2023-07-08 00:00:00            NaN
# max            2023-06-14 00:00:00         2023-07-15 00:00:00            NaN
# std                            NaN                         NaN            NaN
#
#                 Age  Gender  Device Plan Duration  duracao_assinatura
# count   2500.000000    2500    2500          2500         2500.000000
# unique          NaN       2       4             1                 NaN
# top             NaN  Female  Laptop       1 Month                 NaN
# freq            NaN    1257     636          2500                 NaN
# mean      38.795600     NaN     NaN           NaN          308.619200
# min       26.000000     NaN     NaN           NaN            8.000000
# 25%       32.000000     NaN     NaN           NaN          261.000000
# 50%       39.000000     NaN     NaN           NaN          307.000000
# 75%       45.000000     NaN     NaN           NaN          356.000000
# max       51.000000     NaN     NaN           NaN          655.000000
# std        7.171778     NaN     NaN           NaN           63.088172

# %%
df_netflix["duracao_assinatura"] = df_netflix["Last Payment Date"] - df_netflix["Join Date"]
df_netflix
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10 2022-01-15        2023-06-10
# 1           2           Premium               15 2021-09-05        2023-06-22
# 2           3          Standard               12 2023-02-28        2023-06-27
# 3           4          Standard               12 2022-07-10        2023-06-26
# 4           5             Basic               10 2023-05-01        2023-06-28
# ...       ...               ...              ...        ...               ...
# 2495     2496           Premium               14 2022-07-25        2023-07-12
# 2496     2497             Basic               15 2022-08-04        2023-07-14
# 2497     2498          Standard               12 2022-08-09        2023-07-15
# 2498     2499          Standard               13 2022-08-12        2023-07-12
# 2499     2500             Basic               15 2022-08-13        2023-07-12
#
#              Country  Age  Gender      Device Plan Duration duracao_assinatura
# 0      United States   28    Male  Smartphone       1 Month           511 days
# 1             Canada   35  Female      Tablet       1 Month           655 days
# 2     United Kingdom   42    Male    Smart TV       1 Month           119 days
# 3          Australia   51  Female      Laptop       1 Month           351 days
# 4            Germany   33    Male  Smartphone       1 Month            58 days
# ...              ...  ...     ...         ...           ...                ...
# 2495           Spain   28  Female    Smart TV       1 Month           352 days
# 2496           Spain   33  Female    Smart TV       1 Month           344 days
# 2497   United States   38    Male      Laptop       1 Month           340 days
# 2498          Canada   48  Female      Tablet       1 Month           334 days
# 2499   United States   35  Female    Smart TV       1 Month           333 days
#
# [2500 rows x 11 columns]

# %%
df_netflix.dtypes
# Out:
# User ID                         int64
# Subscription Type              object
# Monthly Revenue                 int64
# Join Date              datetime64[ns]
# Last Payment Date      datetime64[ns]
# Country                        object
# Age                             int64
# Gender                         object
# Device                         object
# Plan Duration                  object
# duracao_assinatura    timedelta64[ns]
# dtype: object

# %%
df_netflix["duracao_assinatura"] = df_netflix["duracao_assinatura"].dt.days
#usando o .dt.days tira o nome days da coluna e transfoma a coluna em int - isso é importante porque pode dar erros depois quando for fazer cálculo

df_netflix
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10 2022-01-15        2023-06-10
# 1           2           Premium               15 2021-09-05        2023-06-22
# 2           3          Standard               12 2023-02-28        2023-06-27
# 3           4          Standard               12 2022-07-10        2023-06-26
# 4           5             Basic               10 2023-05-01        2023-06-28
# ...       ...               ...              ...        ...               ...
# 2495     2496           Premium               14 2022-07-25        2023-07-12
# 2496     2497             Basic               15 2022-08-04        2023-07-14
# 2497     2498          Standard               12 2022-08-09        2023-07-15
# 2498     2499          Standard               13 2022-08-12        2023-07-12
# 2499     2500             Basic               15 2022-08-13        2023-07-12
#
#              Country  Age  Gender      Device Plan Duration  \
# 0      United States   28    Male  Smartphone       1 Month
# 1             Canada   35  Female      Tablet       1 Month
# 2     United Kingdom   42    Male    Smart TV       1 Month
# 3          Australia   51  Female      Laptop       1 Month
# 4            Germany   33    Male  Smartphone       1 Month
# ...              ...  ...     ...         ...           ...
# 2495           Spain   28  Female    Smart TV       1 Month
# 2496           Spain   33  Female    Smart TV       1 Month
# 2497   United States   38    Male      Laptop       1 Month
# 2498          Canada   48  Female      Tablet       1 Month
# 2499   United States   35  Female    Smart TV       1 Month
#
#       duracao_assinatura
# 0                    511
# 1                    655
# 2                    119
# 3                    351
# 4                     58
# ...                  ...
# 2495                 352
# 2496                 344
# 2497                 340
# 2498                 334
# 2499                 333
#
# [2500 rows x 11 columns]

# %%
df_netflix.describe()
# Out:
#           User ID  Monthly Revenue                   Join Date  \
# count  2500.00000      2500.000000                        2500
# mean   1250.50000        12.508400  2022-08-28 18:02:52.800000
# min       1.00000        10.000000         2021-09-05 00:00:00
# 25%     625.75000        11.000000         2022-07-15 00:00:00
# 50%    1250.50000        12.000000         2022-08-31 00:00:00
# 75%    1875.25000        14.000000         2022-10-17 00:00:00
# max    2500.00000        15.000000         2023-06-14 00:00:00
# std     721.83216         1.686851                         NaN
#
#                 Last Payment Date          Age  duracao_assinatura
# count                        2500  2500.000000         2500.000000
# mean   2023-07-03 08:54:31.680000    38.795600          308.619200
# min           2023-06-10 00:00:00    26.000000            8.000000
# 25%           2023-06-29 00:00:00    32.000000          261.000000
# 50%           2023-07-03 00:00:00    39.000000          307.000000
# 75%           2023-07-08 00:00:00    45.000000          356.000000
# max           2023-07-15 00:00:00    51.000000          655.000000
# std                           NaN     7.171778           63.088172

# %%
#Extrair dia, mês e ano
df_netflix["dt_mes"] = df_netflix["Join Date"].dt.month
df_netflix["dt_year"] = df_netflix["Join Date"].dt.year
df_netflix.head()

# %%
df_netflix.loc[df_netflix['Age'] < 25, 'grupo_idade'] = '20-24'
df_netflix.loc[(df_netflix['Age'] >= 25) & (df_netflix['Age'] < 30), 'grupo_idade'] = '25-29'
df_netflix.loc[(df_netflix['Age'] >= 30) & (df_netflix['Age'] < 35), 'grupo_idade'] = '30-34'
df_netflix.loc[(df_netflix['Age'] >= 35) & (df_netflix['Age'] < 40), 'grupo_idade'] = '35-39'
df_netflix.loc[(df_netflix['Age'] >= 40) & (df_netflix['Age'] < 45), 'grupo_idade'] = '40-44'
df_netflix.loc[(df_netflix['Age'] >= 45) & (df_netflix['Age'] < 50), 'grupo_idade'] = '45-49'
df_netflix.loc[(df_netflix['Age'] >= 50) & (df_netflix['Age'] < 55), 'grupo_idade'] = '50-54'
df_netflix.loc[(df_netflix['Age'] >= 55) & (df_netflix['Age'] < 60), 'grupo_idade'] = '55-59'
df_netflix.loc[df_netflix['Age'] >= 60, 'grupo_idade'] = '60+'
df_netflix

# %%
import matplotlib as plt
import seaborn as sns

# %%
sns.countplot(data=df_netflix[["grupo_idade"]].sort_values("grupo_idade"), x="grupo_idade")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 sns.countplot(data=df_netflix[["grupo_idade"]].sort_values("grupo_idade"), x="grupo_idade")
#       2 plt.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['grupo_idade'], dtype='object')] are in the [columns]"

# %%
sns.countplot(data=df_netflix[["Subscription Type"]].sort_values("Subscription Type"), x="Subscription Type") 
#countplot já traz a contagem, não traz a média como o barplot
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 2
#       1 sns.countplot(data=df_netflix[["Subscription Type"]].sort_values("Subscription Type"), x="Subscription Type") #countplot já traz a contagem, não traz a média como o barplot
# ----> 2 plt.show
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
sns.countplot(data=df_netflix.sort_values("grupo_idade"), x="Subscription Type", hue="grupo_idade", palette="viridis")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21128\3466342433.py in ?()
# ----> 1 sns.countplot(data=df_netflix.sort_values("grupo_idade"), x="Subscription Type", hue="grupo_idade", palette="viridis")
#       2 plt.show()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'grupo_idade'
