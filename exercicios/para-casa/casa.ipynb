# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_custumers = pd.read_csv(r'C:\Users\bruno\Desktop\REPROG\on33-python-s14-analise-de-dados\customers.csv')
df_custumers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
df_custumers.describe(include ='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     274fa6071e5e17fe303b9748641082c8  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
df_order = pd.read_csv(r'C:\Users\bruno\Desktop\REPROG\on33-python-s14-analise-de-dados\order.csv')
df_order
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
df_order.describe(include ='all')
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     08528f70f579f0c830189efc523d2182  df56136b8031ecd28e200bb18e6ddb2e
# freq                                   3                                 3
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         review_score review_comment_title review_comment_message  \
# ...

# %%
df_pagamento = pd.read_csv(r'C:\Users\bruno\Desktop\REPROG\on33-python-s14-analise-de-dados\payments.csv')
df_pagamento
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
df_pagamento.describe(include ='all')
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
df_itens = pd.read_csv(r'C:\Users\bruno\Desktop\REPROG\on33-python-s14-analise-de-dados\itens.csv')
df_itens
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214            1.0
# 1       00018f77f2f0320c557190d7a144bdd3            1.0
# 2       000229ec398224ef6ca0657da4fc703e            1.0
# 3       00024acbcdf0a6daa1e931b038114c75            1.0
# 4       00042b26cf59d7ce69dfabb4e55b4fd9            1.0
# ...                                  ...            ...
# 112647  fffce4705a9662cd70adb13d4a31832d            1.0
# 112648  fffe18544ffabc95dfada21779c9644f            1.0
# 112649  fffe41c64501cc87c801fd61db3f6244            1.0
# 112650                               NaN            NaN
# 112651                               NaN            NaN
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_itens.describe(include ='all')
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
# Unir df_order com df_pagamento
df_order_payment = pd.merge(df_order, df_pagamento, on='order_id', how='inner')

# Unir o resultado com df_itens
df_full = pd.merge(df_order_payment, df_itens, on='order_id', how='inner')

# Remover as duas últimas colunas pelo nome que constam valores nulos
df_full = df_full.drop(columns=['Unnamed: 7', 'Unnamed: 8'])

# Visualizar a base final
df_full.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 2  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 3  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 4  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
#
#    review_score review_comment_title                 review_comment_message  \
# 0             4                  NaN                                    NaN
# 1             4                  NaN                                    NaN
# 2             5                  NaN                                    NaN
# 3             5                  NaN                                    NaN
# 4             5                  NaN  Recebi bem antes do prazo estipulado.
#
#   review_creation_date review_answer_timestamp  payment_sequential  \
# ...

# %%
# Verificar valores ausentes
df_full.isnull().sum()

# Remover duplicatas
df_full = df_full.drop_duplicates()

# %%
print(df_full.isnull().sum())

df_full = df_full.drop_duplicates()

print("\nDescrição estatística dos dados após remoção de duplicatas:")
print(df_full.describe())
# Out:
# review_id                       0
# order_id                        0
# review_score                    0
# review_comment_title       103439
# review_comment_message      67659
# review_creation_date            0
# review_answer_timestamp         0
# payment_sequential              0
# payment_type                    0
# payment_installments            0
# payment_value                   0
# order_item_id                   0
# product_id                      0
# seller_id                       0
# shipping_limit_date             0
# price                           0
# freight_value                   0
# dtype: int64
#
# Descrição estatística dos dados após remoção de duplicatas:
#         review_score  payment_sequential  payment_installments  payment_value  \
# count  117329.000000       117329.000000         117329.000000  117329.000000
# mean        4.031467            1.094452              2.940151     172.062565
# ...

# %%
#Qual o top  dos vendedores com maior número de vendas?

# Agrupar por 'seller_id' e somar o 'payment_value'
vendedores_vendas = df_full.groupby('seller_id')['payment_value'].sum().reset_index()

# Renomear a coluna para mais clareza
vendedores_vendas = vendedores_vendas.rename(columns={'payment_value': 'total_sales_value'})

# Ordenar os vendedores com base no valor total das vendas em ordem decrescente
vendedores_vendas = vendedores_vendas.sort_values(by='total_sales_value', ascending=False)

# Mostrar os vendedores com mais vendas
print(vendedores_vendas.head())
# Out:
#                              seller_id  total_sales_value
# 1532  7c67e1448b00f6e969d365cea6b010ab          509474.13
# 192   1025f0e2d44d7041d6cf58b6550e0bfa          310579.23
# 878   4a3ca9315b744ce9f8e9374361493884          302403.81
# 368   1f50f920176fa81dab994f9023523100          290729.12
# 1010  53243585a1d6dc2643021fd1853d8905          282750.15

# %%
#Qual os  produtos com maior índice de vendas?

# Agrupar por 'product_id' e somar o número de itens vendidos
produtos_vendas = df_full.groupby('product_id')['order_item_id'].count().reset_index()

# Renomear a coluna para mais clareza
produtos_vendas = produtos_vendas.rename(columns={'order_item_id': 'total_items_sold'})

# Ordenar os produtos com base na quantidade total de itens vendidos em ordem decrescente
produtos_vendas = produtos_vendas.sort_values(by='total_items_sold', ascending=False)

# Mostrar os produtos mais vendidos
print(produtos_vendas.head())
# Out:
#                              product_id  total_items_sold
# 22000  aca2eb7d00ea1a7b8ebd4e68314663af               533
# 19640  99a4788cb24856965c36a24e339b6058               517
# 8562   422879e10f46682990de24d770e7f83d               507
# 7320   389d119b48cf3043d311335e499d9c6b               405
# 7038   368c6c730842d78016ad823897a372db               395

# %%
#Qual é a distribuição de vendas por tipo de pagamento?

# Agrupar por 'payment_type' e somar o 'payment_value'
vendas_por_pagamento = df_full.groupby('payment_type')['payment_value'].sum().reset_index()

# Renomear a coluna para mais clareza
vendas_por_pagamento = vendas_por_pagamento.rename(columns={'payment_value': 'total_sales_value'})

# Ordenar por valor total de vendas em ordem decrescente
vendas_por_pagamento = vendas_por_pagamento.sort_values(by='total_sales_value', ascending=False)

# Mostrar a distribuição das vendas por tipo de pagamento
print(vendas_por_pagamento)
# Out:
#   payment_type  total_sales_value
# 1  credit_card        15488083.56
# 0       boleto         4042302.07
# 3      voucher          403611.39
# 2   debit_card          253931.68

# %%
 #Qual é a relação entre a pontuação das avaliações e o valor total das vendas?
 
 # Agrupar por 'review_score' e somar o 'payment_value'
avaliacoes_vendas = df_full.groupby('review_score')['payment_value'].sum().reset_index()

# Renomear a coluna para mais clareza
avaliacoes_vendas = avaliacoes_vendas.rename(columns={'payment_value': 'total_sales_value'})

# Ordenar por 'review_score' para visualizar a relação
avaliacoes_vendas = avaliacoes_vendas.sort_values(by='review_score')

# Mostrar a relação entre pontuação das avaliações e valor total das vendas
print(avaliacoes_vendas)
# Out:
#    review_score  total_sales_value
# 0             1         3456191.28
# 1             2          782221.49
# 2             3         1649466.99
# 3             4         3643544.01
# 4             5        10656504.93

# %%
# Criar o gráfico de barraplt.figure(figsize=(10, 6))
sns.barplot(data=vendas_por_pagamento, x='payment_type', y='total_sales_value', palette='viridis')
plt.title('Distribuição de Vendas por Tipo de Pagamento')
plt.xlabel('Tipo de Pagamento')
plt.ylabel('Valor Total das Vendas')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\bruno\AppData\Local\Temp\ipykernel_11580\119486106.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=vendas_por_pagamento, x='payment_type', y='total_sales_value', palette='viridis')

# %%
# Criar o gráfico de linhas ou pontos
plt.figure(figsize=(10, 6))
sns.lineplot(data=avaliacoes_vendas, x='review_score', y='total_sales_value', marker='o', linestyle='-')
plt.title('Relação entre Pontuação das Avaliações e Valor Total das Vendas')
plt.xlabel('Pontuação das Avaliações')
plt.ylabel('Valor Total das Vendas')
plt.grid(True)
plt.show()

# %%
# Selecionar os top 5 vendedores para visualização, conforme a pergunta anteriormente feita.
top_vendedores = vendedores_vendas.head(5)

# Criar o gráfico de pizza
plt.figure(figsize=(8, 8))
plt.pie(
    top_vendedores['total_sales_value'],
    labels=top_vendedores['seller_id'],
    autopct='%1.1f%%',
    colors=sns.color_palette('viridis', len(top_vendedores)),
    startangle=140
)
plt.title('Participação dos Melhores Vendedores no Total de Vendas')
plt.show()

# %%
# Exportar o DataFrame df_full para um arquivo CSV
df_full.to_csv('base_final.csv', index=False)
