# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import ttest_ind
import seaborn as sns

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.2-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\biamo\appdata\local\programs\python\python312\lib\site-packages (from statsmodels) (2.0.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\biamo\appdata\local\programs\python\python312\lib\site-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\biamo\appdata\local\programs\python\python312\lib\site-packages (from statsmodels) (2.2.2)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\biamo\appdata\roaming\python\python312\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\biamo\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\biamo\appdata\local\programs\python\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\biamo\appdata\local\programs\python\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in c:\users\biamo\appdata\roaming\python\python312\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.2-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    ------------------------- -------------- 6.3/9.8 MB 22.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 24.5 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.14.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm

# %% [markdown]
# ### Order Payments Dataset

# %%
dfOrderPayment = pd.read_csv(r'C:\git-on33\On33-S14\on33-python-s14-analise-de-dados\exercicios\para-casa\olist_order_payments_dataset.csv')
dfOrderPayment
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# 0                          8          99.33
# 1                          1          24.39
# 2                          1          65.71
# 3                          8         107.78
# 4                          2         128.45
# ...                      ...            ...
# 103881                     1         363.31
# 103882                     2          96.80
# 103883                     1          47.77
# 103884                     5         369.54
# 103885                     1         191.58
#
# [103886 rows x 5 columns]

# %%
dfOrderPayment.describe(include='all')
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# count          103886.000000  103886.000000
# unique                   NaN            NaN
# top                      NaN            NaN
# freq                     NaN            NaN
# mean                2.853349     154.100380
# std                 2.687051     217.494064
# min                 0.000000       0.000000
# 25%                 1.000000      56.790000
# 50%                 1.000000     100.000000
# 75%                 4.000000     171.837500
# max                24.000000   13664.080000

# %%
# Vamos entender um pouquinho melhor dos nossos dados
dfOrderPayment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
## order_id	payment_sequential	payment_type	payment_installments	payment_value
columns_drop = ['payment_sequential']
dfOrderPayment = dfOrderPayment.drop(columns_drop, axis=1)
dfOrderPayment
# Out:
#                                 order_id payment_type  payment_installments  \
# 0       b81ef226f3fe1789b1e8b2acac839d17  credit_card                     8
# 1       a9810da82917af2d9aefd1278f1dcfa0  credit_card                     1
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd  credit_card                     1
# 3       ba78997921bbcdc1373bb41e913ab953  credit_card                     8
# 4       42fdf880ba16b47b59251dd489d4441a  credit_card                     2
# ...                                  ...          ...                   ...
# 103881  0406037ad97740d563a178ecc7a2075c       boleto                     1
# 103882  7b905861d7c825891d6347454ea7863f  credit_card                     2
# 103883  32609bbb3dd69b3c066a6860554a77bf  credit_card                     1
# 103884  b8b61059626efa996a60be9bb9320e10  credit_card                     5
# 103885  28bbae6599b09d39ca406b747b6632b1       boleto                     1
#
#         payment_value
# 0               99.33
# 1               24.39
# 2               65.71
# 3              107.78
# 4              128.45
# ...               ...
# 103881         363.31
# 103882          96.80
# 103883          47.77
# 103884         369.54
# 103885         191.58
#
# [103886 rows x 4 columns]

# %% [markdown]
# ### Order Reviews Dataset

# %%
dfOrderReview = pd.read_csv(r'C:\git-on33\On33-S14\on33-python-s14-analise-de-dados\exercicios\para-casa\olist_order_reviews_dataset.csv')
dfOrderReview
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 0                 4                  NaN
# 1                 5                  NaN
# 2                 5                  NaN
# 3                 5                  NaN
# 4                 5                  NaN
# ...             ...                  ...
# 99219             5                  NaN
# 99220             5                  NaN
# 99221             5                  NaN
# 99222             4                  NaN
# 99223             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 0                                                    NaN  2018-01-18 00:00:00
# 1                                                    NaN  2018-03-10 00:00:00
# 2                                                    NaN  2018-02-17 00:00:00
# 3                  Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4      Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# ...                                                  ...                  ...
# 99219                                                NaN  2018-07-07 00:00:00
# 99220                                                NaN  2017-12-09 00:00:00
# 99221  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 99222                                                NaN  2018-07-01 00:00:00
# 99223  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp
# 0         2018-01-18 21:46:59
# 1         2018-03-11 03:05:13
# 2         2018-02-18 14:36:24
# 3         2017-04-21 22:02:06
# 4         2018-03-02 10:26:53
# ...                       ...
# 99219     2018-07-14 17:18:30
# 99220     2017-12-11 20:06:42
# 99221     2018-03-23 09:10:43
# 99222     2018-07-02 12:59:13
# 99223     2017-07-03 21:01:49
#
# [99224 rows x 7 columns]

# %%
dfOrderReview.describe(include='all')
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     08528f70f579f0c830189efc523d2182  df56136b8031ecd28e200bb18e6ddb2e
# freq                                   3                                 3
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         review_score review_comment_title review_comment_message  \
# count   99224.000000                11568                  40977
# unique           NaN                 4527                  36159
# top              NaN            Recomendo              Muito bom
# freq             NaN                  423                    230
# mean        4.086421                  NaN                    NaN
# std         1.347579                  NaN                    NaN
# min         1.000000                  NaN                    NaN
# 25%         4.000000                  NaN                    NaN
# 50%         5.000000                  NaN                    NaN
# 75%         5.000000                  NaN                    NaN
# max         5.000000                  NaN                    NaN
#
#        review_creation_date review_answer_timestamp
# count                 99224                   99224
# unique                  636                   98248
# top     2017-12-19 00:00:00     2017-06-15 23:21:05
# freq                    463                       4
# mean                    NaN                     NaN
# std                     NaN                     NaN
# min                     NaN                     NaN
# 25%                     NaN                     NaN
# 50%                     NaN                     NaN
# 75%                     NaN                     NaN
# max                     NaN                     NaN

# %%
dfOrderReview.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
dfOrderReview = dfOrderReview.dropna(axis=0)
dfOrderReview.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9839 entries, 9 to 99200
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                9839 non-null   object
#  1   order_id                 9839 non-null   object
#  2   review_score             9839 non-null   int64
#  3   review_comment_title     9839 non-null   object
#  4   review_comment_message   9839 non-null   object
#  5   review_creation_date     9839 non-null   object
#  6   review_answer_timestamp  9839 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 614.9+ KB

# %%
columns_drop = ['review_answer_timestamp', 'review_id']
dfOrderReview = dfOrderReview.drop(columns_drop, axis=1)
dfOrderReview
# Out:
#                                order_id  review_score  \
# 9      b9bf720beb4ab3728760088589c62129             4
# 15     e51478e7e277a83743b6f9991dbfa3fb             5
# 19     583174fbe37d3d5f0d6661be3aad1786             1
# 22     4fc44d78867142c627497b60a7e0228a             5
# 34     37e7875cdce5a9e5b3a692971f370151             4
# ...                                 ...           ...
# 99187  16cbf959cfdb88c47ee2a29303547ec2             5
# 99192  bd78f91afbb1ecbc6124974c5e813043             4
# 99196  0ebf8e35b9807ee2d717922d5663ccdb             5
# 99197  b7467ae483dbe956fe9acdf0b1e6e3f4             3
# 99200  f2d12dd37eaef72ed7b1186b2edefbcd             2
#
#             review_comment_title  \
# 9                      recomendo
# 15               Super recomendo
# 19       Não chegou meu produto
# 22                         Ótimo
# 34                    Muito bom.
# ...                          ...
# 99187               Nota máxima!
# 99192                          👍
# 99196         muito bom produto
# 99197  Não foi entregue o pedido
# 99200             Foto enganosa
#
#                                   review_comment_message review_creation_date
# 9      aparelho eficiente. no site a marca do aparelh...  2018-05-22 00:00:00
# 15     Vendedor confiável, produto ok e entrega antes...  2018-05-23 00:00:00
# 19                                               Péssimo  2018-08-15 00:00:00
# 22                                          Loja nota 10  2018-07-10 00:00:00
# 34     Recebi exatamente o que esperava. As demais en...  2018-06-07 00:00:00
# ...                                                  ...                  ...
# 99187  Muito obrigado,\r\n\r\nExcelente atendimento,b...  2018-05-22 00:00:00
# 99192                                          Aprovado!  2018-07-04 00:00:00
# 99196  Ficamos muito satisfeitos com o produto, atend...  2018-06-30 00:00:00
# 99197  Bom dia \r\nDas 6 unidades compradas só recebi...  2018-06-05 00:00:00
# 99200  Foto muito diferente principalmente a graninha...  2018-03-28 00:00:00
#
# [9839 rows x 5 columns]

# %%
# Vamos transformar nossas colunas de data (que estão como string) em data: 
dfOrderReview['review_creation_date'] = pd.to_datetime(dfOrderReview['review_creation_date'])

# Agora sim, vamos criar uma coluna de data e de mês!
dfOrderReview['reference_date'] = dfOrderReview['review_creation_date'].dt.date
dfOrderReview['reference_YearMonth'] = dfOrderReview['review_creation_date'].dt.strftime('%Y-%m')
dfOrderReview
# Out:
#                                order_id  review_score  \
# 9      b9bf720beb4ab3728760088589c62129             4
# 15     e51478e7e277a83743b6f9991dbfa3fb             5
# 19     583174fbe37d3d5f0d6661be3aad1786             1
# 22     4fc44d78867142c627497b60a7e0228a             5
# 34     37e7875cdce5a9e5b3a692971f370151             4
# ...                                 ...           ...
# 99187  16cbf959cfdb88c47ee2a29303547ec2             5
# 99192  bd78f91afbb1ecbc6124974c5e813043             4
# 99196  0ebf8e35b9807ee2d717922d5663ccdb             5
# 99197  b7467ae483dbe956fe9acdf0b1e6e3f4             3
# 99200  f2d12dd37eaef72ed7b1186b2edefbcd             2
#
#             review_comment_title  \
# 9                      recomendo
# 15               Super recomendo
# 19       Não chegou meu produto
# 22                         Ótimo
# 34                    Muito bom.
# ...                          ...
# 99187               Nota máxima!
# 99192                          👍
# 99196         muito bom produto
# 99197  Não foi entregue o pedido
# 99200             Foto enganosa
#
#                                   review_comment_message review_creation_date  \
# 9      aparelho eficiente. no site a marca do aparelh...           2018-05-22
# 15     Vendedor confiável, produto ok e entrega antes...           2018-05-23
# 19                                               Péssimo           2018-08-15
# 22                                          Loja nota 10           2018-07-10
# 34     Recebi exatamente o que esperava. As demais en...           2018-06-07
# ...                                                  ...                  ...
# 99187  Muito obrigado,\r\n\r\nExcelente atendimento,b...           2018-05-22
# 99192                                          Aprovado!           2018-07-04
# 99196  Ficamos muito satisfeitos com o produto, atend...           2018-06-30
# 99197  Bom dia \r\nDas 6 unidades compradas só recebi...           2018-06-05
# 99200  Foto muito diferente principalmente a graninha...           2018-03-28
#
#       reference_date reference_YearMonth
# 9         2018-05-22             2018-05
# 15        2018-05-23             2018-05
# 19        2018-08-15             2018-08
# 22        2018-07-10             2018-07
# 34        2018-06-07             2018-06
# ...              ...                 ...
# 99187     2018-05-22             2018-05
# 99192     2018-07-04             2018-07
# 99196     2018-06-30             2018-06
# 99197     2018-06-05             2018-06
# 99200     2018-03-28             2018-03
#
# [9839 rows x 7 columns]

# %% [markdown]
# ### Orders Dataset

# %%
dfOrders = pd.read_csv(r'C:\git-on33\On33-S14\on33-python-s14-analise-de-dados\exercicios\para-casa\olist_orders_dataset.csv')
dfOrders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 0        delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
# ...            ...                      ...                  ...
# 99436    delivered      2017-03-09 09:54:05  2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date
# 0               2017-10-18 00:00:00
# 1               2018-08-13 00:00:00
# 2               2018-09-04 00:00:00
# 3               2017-12-15 00:00:00
# 4               2018-02-26 00:00:00
# ...                             ...
# 99436           2017-03-28 00:00:00
# 99437           2018-03-02 00:00:00
# 99438           2017-09-27 00:00:00
# 99439           2018-02-15 00:00:00
# 99440           2018-04-03 00:00:00
#
# [99441 rows x 8 columns]

# %%
dfOrders.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-08-02 12:05:26  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# top             2018-05-09 15:48:00           2018-05-08 19:36:48
# freq                             47                             3
#
#        order_estimated_delivery_date
# count                          99441
# unique                           459
# top              2017-12-20 00:00:00
# freq                             522

# %%
dfOrders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
columns_drop = ['customer_id', 'order_purchase_timestamp', 'order_delivered_carrier_date']
dfOrders = dfOrders.drop(columns_drop, axis=1)
dfOrders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   order_status                   99441 non-null  object
#  2   order_approved_at              99281 non-null  object
#  3   order_delivered_customer_date  96476 non-null  object
#  4   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(5)
# memory usage: 3.8+ MB

# %%
# DATA DA COMPRA
dfOrders['order_approved_at'] = pd.to_datetime(dfOrders['order_approved_at'])

dfOrders['DataFaturamento'] = dfOrders['order_approved_at'].dt.normalize()


# DATA DA ENTREGA
dfOrders['order_delivered_customer_date'] = pd.to_datetime(dfOrders['order_delivered_customer_date'])

dfOrders['DataEntrega'] = dfOrders['order_delivered_customer_date'].dt.normalize()

# DATA ESTIMADA PA ENTREGA
dfOrders['order_estimated_delivery_date'] = pd.to_datetime(dfOrders['order_estimated_delivery_date'])

dfOrders['DataEntEstimada'] = dfOrders['order_estimated_delivery_date'].dt.normalize()

dfOrders
# Out:
#                                order_id order_status   order_approved_at  \
# 0      e481f51cbdc54678b7cc49136f2d6af7    delivered 2017-10-02 11:07:15
# 1      53cdb2fc8bc7dce0b6741e2150273451    delivered 2018-07-26 03:24:27
# 2      47770eb9100c2d0c44946d9cf07ec65d    delivered 2018-08-08 08:55:23
# 3      949d5b44dbf5de918fe9c16f97b45f8a    delivered 2017-11-18 19:45:59
# 4      ad21c59c0840e6cb83a9ceb5573f8159    delivered 2018-02-13 22:20:29
# ...                                 ...          ...                 ...
# 99436  9c5dedf39a927c1b2549525ed64a053c    delivered 2017-03-09 09:54:05
# 99437  63943bddc261676b46f01ca7ac2f7bd8    delivered 2018-02-06 13:10:37
# 99438  83c1379a015df1e13d02aae0204711ab    delivered 2017-08-27 15:04:16
# 99439  11c177c8e97725db2631073c19f07b62    delivered 2018-01-08 21:36:21
# 99440  66dea50a8b16d9b4dee7af250b4be1a5    delivered 2018-03-09 11:20:28
#
#       order_delivered_customer_date order_estimated_delivery_date  \
# 0               2017-10-10 21:25:13                    2017-10-18
# 1               2018-08-07 15:27:45                    2018-08-13
# 2               2018-08-17 18:06:29                    2018-09-04
# 3               2017-12-02 00:28:42                    2017-12-15
# 4               2018-02-16 18:17:02                    2018-02-26
# ...                             ...                           ...
# 99436           2017-03-17 15:08:01                    2017-03-28
# 99437           2018-02-28 17:37:56                    2018-03-02
# 99438           2017-09-21 11:24:17                    2017-09-27
# 99439           2018-01-25 23:32:54                    2018-02-15
# 99440           2018-03-16 13:08:30                    2018-04-03
#
#       DataFaturamento DataEntrega DataEntEstimada
# 0          2017-10-02  2017-10-10      2017-10-18
# 1          2018-07-26  2018-08-07      2018-08-13
# 2          2018-08-08  2018-08-17      2018-09-04
# 3          2017-11-18  2017-12-02      2017-12-15
# 4          2018-02-13  2018-02-16      2018-02-26
# ...               ...         ...             ...
# 99436      2017-03-09  2017-03-17      2017-03-28
# 99437      2018-02-06  2018-02-28      2018-03-02
# 99438      2017-08-27  2017-09-21      2017-09-27
# 99439      2018-01-08  2018-01-25      2018-02-15
# 99440      2018-03-09  2018-03-16      2018-04-03
#
# [99441 rows x 8 columns]

# %%
columns_drop = ['order_approved_at', 'order_delivered_customer_date', 'order_estimated_delivery_date']
dfOrders = dfOrders.drop(columns_drop, axis=1)
dfOrders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         99441 non-null  object
#  1   order_status     99441 non-null  object
#  2   DataFaturamento  99281 non-null  datetime64[ns]
#  3   DataEntrega      96476 non-null  datetime64[ns]
#  4   DataEntEstimada  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), object(2)
# memory usage: 3.8+ MB

# %% [markdown]
# ### Joins

# %%
dfJoinOrders = pd.merge(dfOrderPayment, dfOrderReview, on=['order_id'], how='inner')
dfJoinOrders
# Out:
#                                order_id payment_type  payment_installments  \
# 0      b81ef226f3fe1789b1e8b2acac839d17  credit_card                     8
# 1      298fcdf1f73eb413e4d26d01b25bc1cd  credit_card                     2
# 2      1f78449c87a54faf9e96e88ba1491fa9  credit_card                     6
# 3      616105c9352a9668c38303ad44e056cd  credit_card                     1
# 4      79da3f5fe31ad1e454f06f95dc032ad5  credit_card                     1
# ...                                 ...          ...                   ...
# 10217  2ab10ab526351fd3b05219e9eb4f7d9f  credit_card                     8
# 10218  31b39339d93a6949e2f2addf798d8904  credit_card                     1
# 10219  93c244c6bb63cafcde3117a2b2a5e151  credit_card                    10
# 10220  38d11c87fc409de31e930084abb0c7a4  credit_card                     7
# 10221  60aed0a4eba0e424eb3cac85017fd752  credit_card                    10
#
#        payment_value  review_score  review_comment_title  \
# 0              99.33             1         Não recomendo
# 1              96.12             5                    10
# 2             341.09             5             Muito bom
# 3              75.78             2               Regular
# 4              98.94             5             recomendo
# ...              ...           ...                   ...
# 10217         366.73             5             recomendo
# 10218         114.49             5             Perfeito!
# 10219         195.86             2   Embalagem horrorosa
# 10220          91.03             5  MUITO BOA AMERICANA
# 10221         170.14             5                     5
#
#                                   review_comment_message review_creation_date  \
# 0      Produto com qualidade ruim, amassado e descasc...           2018-05-10
# 1                                        Muito bom!!\r\n           2018-05-15
# 2                                                 Gostei           2018-07-29
# 3      Comprei 2 produtos chegou apenas 1. Aguardo re...           2018-06-22
# 4      ESTOU MUITO SATISFEITA COM OS PRODUTOS E ATEND...           2018-06-14
# ...                                                  ...                  ...
# 10217  produto veio antes do prazo, muito bem embalad...           2018-06-21
# 10218  Produto de ótima qualidade, bem embalado e ent...           2018-08-01
# 10219  O produto vendido pela targaryen chegou em uma...           2018-05-11
# 10220                  Ótima rápida na entrega OBRIGADO            2018-08-25
# 10221  super indico , pois o produto chegou em perfei...           2018-06-23
#
#       reference_date reference_YearMonth
# 0         2018-05-10             2018-05
# 1         2018-05-15             2018-05
# 2         2018-07-29             2018-07
# 3         2018-06-22             2018-06
# 4         2018-06-14             2018-06
# ...              ...                 ...
# 10217     2018-06-21             2018-06
# 10218     2018-08-01             2018-08
# 10219     2018-05-11             2018-05
# 10220     2018-08-25             2018-08
# 10221     2018-06-23             2018-06
#
# [10222 rows x 10 columns]

# %%
dfJoinOrdersII = pd.merge(dfJoinOrders, dfOrders, on=['order_id'], how='inner')
dfJoinOrdersII
# Out:
#                                order_id payment_type  payment_installments  \
# 0      b81ef226f3fe1789b1e8b2acac839d17  credit_card                     8
# 1      298fcdf1f73eb413e4d26d01b25bc1cd  credit_card                     2
# 2      1f78449c87a54faf9e96e88ba1491fa9  credit_card                     6
# 3      616105c9352a9668c38303ad44e056cd  credit_card                     1
# 4      79da3f5fe31ad1e454f06f95dc032ad5  credit_card                     1
# ...                                 ...          ...                   ...
# 10217  2ab10ab526351fd3b05219e9eb4f7d9f  credit_card                     8
# 10218  31b39339d93a6949e2f2addf798d8904  credit_card                     1
# 10219  93c244c6bb63cafcde3117a2b2a5e151  credit_card                    10
# 10220  38d11c87fc409de31e930084abb0c7a4  credit_card                     7
# 10221  60aed0a4eba0e424eb3cac85017fd752  credit_card                    10
#
#        payment_value  review_score  review_comment_title  \
# 0              99.33             1         Não recomendo
# 1              96.12             5                    10
# 2             341.09             5             Muito bom
# 3              75.78             2               Regular
# 4              98.94             5             recomendo
# ...              ...           ...                   ...
# 10217         366.73             5             recomendo
# 10218         114.49             5             Perfeito!
# 10219         195.86             2   Embalagem horrorosa
# 10220          91.03             5  MUITO BOA AMERICANA
# 10221         170.14             5                     5
#
#                                   review_comment_message review_creation_date  \
# 0      Produto com qualidade ruim, amassado e descasc...           2018-05-10
# 1                                        Muito bom!!\r\n           2018-05-15
# 2                                                 Gostei           2018-07-29
# 3      Comprei 2 produtos chegou apenas 1. Aguardo re...           2018-06-22
# 4      ESTOU MUITO SATISFEITA COM OS PRODUTOS E ATEND...           2018-06-14
# ...                                                  ...                  ...
# 10217  produto veio antes do prazo, muito bem embalad...           2018-06-21
# 10218  Produto de ótima qualidade, bem embalado e ent...           2018-08-01
# 10219  O produto vendido pela targaryen chegou em uma...           2018-05-11
# 10220                  Ótima rápida na entrega OBRIGADO            2018-08-25
# 10221  super indico , pois o produto chegou em perfei...           2018-06-23
#
#       reference_date reference_YearMonth order_status DataFaturamento  \
# 0         2018-05-10             2018-05    delivered      2018-04-25
# 1         2018-05-15             2018-05    delivered      2018-05-07
# 2         2018-07-29             2018-07    delivered      2018-07-23
# 3         2018-06-22             2018-06    delivered      2018-06-11
# 4         2018-06-14             2018-06    delivered      2018-06-05
# ...              ...                 ...          ...             ...
# 10217     2018-06-21             2018-06    delivered      2018-06-13
# 10218     2018-08-01             2018-08    delivered      2018-07-29
# 10219     2018-05-11             2018-05    delivered      2018-05-03
# 10220     2018-08-25             2018-08    delivered      2018-08-17
# 10221     2018-06-23             2018-06    delivered      2018-06-18
#
#       DataEntrega DataEntEstimada
# 0      2018-05-09      2018-05-22
# 1      2018-05-14      2018-05-23
# 2      2018-07-28      2018-08-14
# 3      2018-06-21      2018-06-29
# 4      2018-06-13      2018-07-12
# ...           ...             ...
# 10217  2018-06-20      2018-07-03
# 10218  2018-07-31      2018-08-02
# 10219  2018-05-10      2018-05-22
# 10220  2018-08-24      2018-09-03
# 10221  2018-06-22      2018-07-19
#
# [10222 rows x 14 columns]

# %%
dfJoinOrdersII.to_csv('PedidosOlist.csv', index=False)

# %% [markdown]
# ### Analisando os Dados

# %%
dfJoinOrdersII.head()
# Out:
#                            order_id payment_type  payment_installments  \
# 0  b81ef226f3fe1789b1e8b2acac839d17  credit_card                     8
# 1  298fcdf1f73eb413e4d26d01b25bc1cd  credit_card                     2
# 2  1f78449c87a54faf9e96e88ba1491fa9  credit_card                     6
# 3  616105c9352a9668c38303ad44e056cd  credit_card                     1
# 4  79da3f5fe31ad1e454f06f95dc032ad5  credit_card                     1
#
#    payment_value  review_score review_comment_title  \
# 0          99.33             1        Não recomendo
# 1          96.12             5                   10
# 2         341.09             5            Muito bom
# 3          75.78             2              Regular
# 4          98.94             5            recomendo
#
#                               review_comment_message review_creation_date  \
# 0  Produto com qualidade ruim, amassado e descasc...           2018-05-10
# 1                                    Muito bom!!\r\n           2018-05-15
# 2                                             Gostei           2018-07-29
# 3  Comprei 2 produtos chegou apenas 1. Aguardo re...           2018-06-22
# 4  ESTOU MUITO SATISFEITA COM OS PRODUTOS E ATEND...           2018-06-14
#
#   reference_date reference_YearMonth order_status DataFaturamento DataEntrega  \
# 0     2018-05-10             2018-05    delivered      2018-04-25  2018-05-09
# 1     2018-05-15             2018-05    delivered      2018-05-07  2018-05-14
# 2     2018-07-29             2018-07    delivered      2018-07-23  2018-07-28
# 3     2018-06-22             2018-06    delivered      2018-06-11  2018-06-21
# 4     2018-06-14             2018-06    delivered      2018-06-05  2018-06-13
#
#   DataEntEstimada
# 0      2018-05-22
# 1      2018-05-23
# 2      2018-08-14
# 3      2018-06-29
# 4      2018-07-12

# %% [markdown]
# #### Qual a forma de pagto mais frequente entre os clientes?

# %%
dfJoinOrdersII['payment_type'].unique()
# Out:
# array(['credit_card', 'voucher', 'boleto', 'debit_card', 'not_defined'],
#       dtype=object)

# %%
dfJoinOrdersII['payment_type'].value_counts()
# Out:
# payment_type
# credit_card    7624
# boleto         1771
# voucher         533
# debit_card      292
# not_defined       2
# Name: count, dtype: int64

# %%
PaymentType = dfJoinOrdersII['payment_type'].value_counts()

#criando o grafico
barras = PaymentType.plot.bar(color='blue')

#configurações
plt.xlabel('Tipo de Pagamento')
plt.xticks(rotation=0)
plt.ylabel('Quantidade')
plt.title('Tipos de Pagamentos mais usados')

# Adicionar rótulos nos graficos
for i, v in enumerate(PaymentType):
    barras.text(i, v + 0.01, f'{v}', color='black', ha='center')

plt.show()

# %%
## Notei que os clientes tem preferencia por pagar com o Cartao de Credito, então agora, veremos de quantas vezes eles costumam parcelar.
CreditCard = dfJoinOrdersII[dfJoinOrdersII['payment_type'].str.contains('credit_card', case=False, na=False)]

Installments = CreditCard['payment_installments'].value_counts()

#criando o grafico
barras = Installments.plot.bar(color='blue')

#configurações
plt.xlabel('Tipo de Pagamento')
plt.xticks(rotation=0)
plt.ylabel('Quantidade')
plt.title('Tipos de Pagamentos mais usados')

# Adicionar rótulos nos graficos
for i, v in enumerate(Installments):
    barras.text(i, v + 0.01, f'{v}', color='black', ha='center')

plt.show()

# %%
## Mesmo os clientes preferindo pagar no cartão de crédito, percebemos que eles passam à vista.

# %% [markdown]
# #### As entregas estão sendo feitas dentro do prazo?

# %%
dfJoinOrdersII['Difference'] = (dfJoinOrdersII['DataEntEstimada'] - dfJoinOrdersII['DataEntrega']).dt.days


dfJoinOrdersII['DeliveryStatus'] = np.where(dfJoinOrdersII['Difference'] > 0, 'Entregue antes do prazo',
                                 np.where(dfJoinOrdersII['Difference'] == 0, 'Entregue no Prazo',
                                          'Entregue com Atraso'))


#criando o grafico
Diff = dfJoinOrdersII['DeliveryStatus'].value_counts()

cores = ['green', 'red', 'blue']
barras = Diff.plot.bar(color=cores)

#configurações
plt.xlabel('Status')
plt.xticks(rotation=0)
plt.ylabel('Quantidade')
plt.title('Tempo de Entrega')

# Adicionar rótulos nos graficos
for i, v in enumerate(Diff):
    barras.text(i, v + 0.01, f'{v}', color='black', ha='center')

plt.show()

# %% [markdown]
# ### O tempo da entrega influencia na nota?

# %%
# Criando a nova coluna 'InTime'
dfJoinOrdersII['InTime'] = dfJoinOrdersII['Difference'].apply(lambda x: 1 if x >= 0 else 0)
dfJoinOrdersII.head()
# Out:
#                            order_id payment_type  payment_installments  \
# 0  b81ef226f3fe1789b1e8b2acac839d17  credit_card                     8
# 1  298fcdf1f73eb413e4d26d01b25bc1cd  credit_card                     2
# 2  1f78449c87a54faf9e96e88ba1491fa9  credit_card                     6
# 3  616105c9352a9668c38303ad44e056cd  credit_card                     1
# 4  79da3f5fe31ad1e454f06f95dc032ad5  credit_card                     1
#
#    payment_value  review_score review_comment_title  \
# 0          99.33             1        Não recomendo
# 1          96.12             5                   10
# 2         341.09             5            Muito bom
# 3          75.78             2              Regular
# 4          98.94             5            recomendo
#
#                               review_comment_message review_creation_date  \
# 0  Produto com qualidade ruim, amassado e descasc...           2018-05-10
# 1                                    Muito bom!!\r\n           2018-05-15
# 2                                             Gostei           2018-07-29
# 3  Comprei 2 produtos chegou apenas 1. Aguardo re...           2018-06-22
# 4  ESTOU MUITO SATISFEITA COM OS PRODUTOS E ATEND...           2018-06-14
#
#   reference_date reference_YearMonth order_status DataFaturamento DataEntrega  \
# 0     2018-05-10             2018-05    delivered      2018-04-25  2018-05-09
# 1     2018-05-15             2018-05    delivered      2018-05-07  2018-05-14
# 2     2018-07-29             2018-07    delivered      2018-07-23  2018-07-28
# 3     2018-06-22             2018-06    delivered      2018-06-11  2018-06-21
# 4     2018-06-14             2018-06    delivered      2018-06-05  2018-06-13
#
#   DataEntEstimada  Difference           DeliveryStatus  InTime
# 0      2018-05-22        13.0  Entregue antes do prazo       1
# 1      2018-05-23         9.0  Entregue antes do prazo       1
# 2      2018-08-14        17.0  Entregue antes do prazo       1
# 3      2018-06-29         8.0  Entregue antes do prazo       1
# 4      2018-07-12        29.0  Entregue antes do prazo       1

# %%
# Amostras
inTime = dfJoinOrdersII[dfJoinOrdersII['InTime'] == 1]['review_score'].dropna()
late = dfJoinOrdersII[dfJoinOrdersII['InTime'] == 0]['review_score'].dropna()

# Teste T - Hipótese Unicaudal (mais satisfeitos ganham mais)
estatistica_t, valor_p_bicaudal = ttest_ind(late, inTime, equal_var=False)

# Dividindo o valor-p por 2 para o teste unicaudal
valor_p_unicaudal = valor_p_bicaudal / 2

print("Teste T de Avaliação (Unicaudal)")
print(f"Estatística T: {estatistica_t}")
print(f"Valor P (Unicaudal): {valor_p_unicaudal}")

# Gráfico
sns.histplot(inTime, color='lightblue', label='No Prazo', kde=True)
sns.histplot(late, color='red', label='Atraso', kde=True)

# Rótulos
plt.legend()
plt.title("Satisfação dos clientes por Tempo de Entrega")
plt.xlabel("Status Entrega")
plt.ylabel("Contagem")
plt.show()

# Interpretação
if estatistica_t > 0 and valor_p_unicaudal < 0.05:
    print("Rejeitamos a hipótese nula: Não há evidência suficiente para afirmar que os clientes mais satisfeitos recebem a compra No Prazo.")
else:
    print("Não rejeitamos a hipótese nula: Clientes que recebem suas compras No Prazo tendem a ficar mais Satisfeitos.")
# Out:
# Teste T de Avaliação (Unicaudal)
# Estatística T: -42.32105207747439
# Valor P (Unicaudal): 1.262344046649296e-243
# Não rejeitamos a hipótese nula: Clientes que recebem suas compras No Prazo tendem a ficar mais Satisfeitos.
