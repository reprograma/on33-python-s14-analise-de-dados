# %% [markdown]
# # **Análise exploratória**
# - base de dados da Olist
#
# Para ter acesso à base de dados, acesse: https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce, ou baixe através do link:
#
#  https://drive.google.com/drive/folders/1RuibSOdMp-cR6niAdbH8bRIj3PO4EOlh?usp=sharing

# %% [markdown]
# ## **Bibliotecas utilizadas**

# %%
# Importando as bibliotecas necessárias
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Coleta**

# %%
#Importando a base de dados diretamente do Github
url_pedidos = "https://raw.githubusercontent.com/CarolyneS14/on33-python-s14-analise-de-dados/main/material/dados/olist_orders_dataset.csv"

#Transformando a base em um DataFrame
df_pedidos = pd.read_csv(url_pedidos)

#Visualizando o DataFrame(df)
df_pedidos
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
#Importando a base de dados diretamente do Github
url_itens_pedido = "https://raw.githubusercontent.com/CarolyneS14/on33-python-s14-analise-de-dados/main/material/dados/olist_order_items_dataset.csv"

#Transformando a base em um DataFrame
df_itens_pedido = pd.read_csv(url_itens_pedido)

#Visualizando o DataFrame(df)
df_itens_pedido
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
#Importando a base de dados diretamente do Github
url_consumidor = "https://raw.githubusercontent.com/CarolyneS14/on33-python-s14-analise-de-dados/main/material/dados/olist_customers_dataset.csv"

#Transformando a base em um DataFrame
df_consumidor = pd.read_csv(url_consumidor)

#Visualizando o DataFrame(df)
df_consumidor
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
#Importando a base de dados diretamente do Github
url_vendedor = "https://raw.githubusercontent.com/CarolyneS14/on33-python-s14-analise-de-dados/main/Carolyne-Oliveira/para-casa/Bases_Olist_Utilizadas/olist_sellers_dataset.csv"

#Transformando a base em um DataFrame
df_vendedor = pd.read_csv(url_vendedor)

#Visualizando o DataFrame(df)
df_vendedor
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
#Importando a base de dados diretamente do Github
url_produtos = "https://raw.githubusercontent.com/CarolyneS14/on33-python-s14-analise-de-dados/main/Carolyne-Oliveira/para-casa/Bases_Olist_Utilizadas/olist_products_dataset.csv"

#Transformando a base em um DataFrame
df_produtos = pd.read_csv(url_produtos)

#Visualizando o DataFrame(df)
df_produtos
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %% [markdown]
# ## **Limpeza**

# %%
#Estatísticas descritivas sobre o DataFrame
df_pedidos.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-08-02 12:05:26  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %%
#Estatísticas descritivas sobre o DataFrame
df_itens_pedido.describe(include='all')
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
#Estatísticas descritivas sobre o DataFrame
df_consumidor.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     274fa6071e5e17fe303b9748641082c8  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
#Estatísticas descritivas sobre o DataFrame
df_produtos.describe(include='all')
# Out:
#                               product_id product_category_name  \
# count                              32951                 32341
# unique                             32951                    73
# top     106392145fca363410d287a815be6de4       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32341.000000                32341.000000        32341.000000
# ...

# %%
#Estatísticas descritivas sobre o DataFrame
df_vendedor.describe(include='all')
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     9e25199f6ef7e7c347120ff175652c3b                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# ...

# %% [markdown]
# - JOIN

# %%
#Merge para unir o df_pedidos e o df_itens_pedido
df_olist_pedidos = pd.merge(df_pedidos, df_itens_pedido, on=['order_id'], how='inner')
df_olist_pedidos
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
# Verificar as colunas depois do JOIN
df_olist_pedidos[df_olist_pedidos.price.isna() == True]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value]
# Index: []

# %%
#Merge para unir o novo df_olist_pedidos e o df_consumidor
df_olist_pedidos_uf = pd.merge(df_olist_pedidos, df_consumidor, on=['customer_id'], how='inner')
df_olist_pedidos_uf
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
# Verificar as colunas depois do JOIN
df_olist_pedidos_uf[df_olist_pedidos_uf.price.isna() == True]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state]
# Index: []

# %%
#Merge para unir o novo df_olist_pedidos_uf e o df_produtos
df_olist_pedidos_uf_prod = pd.merge(df_olist_pedidos_uf, df_produtos, on=['product_id'], how='inner')
df_olist_pedidos_uf_prod
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
# Verificar as colunas depois do JOIN
df_olist_pedidos_uf_prod[df_olist_pedidos_uf_prod.price.isna() == True]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state, product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm]
# Index: []
#
# [0 rows x 26 columns]

# %%
#Merge para unir o novo df_olist_pedidos_uf_prod e o df_produtos
df_vendas_olist = pd.merge(df_olist_pedidos_uf_prod, df_vendedor, on=['seller_id'], how='inner')
df_vendas_olist
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
# Verificar as colunas depois do JOIN
df_vendas_olist[df_vendas_olist.price.isna() == True]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state, product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm, seller_zip_code_prefix, seller_city, seller_state]
# Index: []
#
# [0 rows x 29 columns]

# %%
# Vamos entender um pouquinho melhor dos nossos dados
df_vendas_olist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  object
#  1   customer_id                    112650 non-null  object
#  2   order_status                   112650 non-null  object
#  3   order_purchase_timestamp       112650 non-null  object
#  4   order_approved_at              112635 non-null  object
#  5   order_delivered_carrier_date   111456 non-null  object
#  6   order_delivered_customer_date  110196 non-null  object
#  7   order_estimated_delivery_date  112650 non-null  object
#  8   order_item_id                  112650 non-null  int64
#  9   product_id                     112650 non-null  object
#  10  seller_id                      112650 non-null  object
#  11  shipping_limit_date            112650 non-null  object
# ...

# %% [markdown]
# - Excluir Colunas

# %%
#Verificar valores nulos
df_vendas_olist[df_vendas_olist.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 5971   e04abd8149ef81b95221e88f6ed9ab6a  2127dc6603ac33544953ef05ec155771
# 18732  8a9adc69528e1001fc68dd0aaebbb54a  4c1ccc74e00993733742a3c786dc3c1f
# 21512  7013bcfc1c97fe719a7b5e05e61c12db  2941af76d38100e0f8740a374f1a5dc3
# 25620  5cf925b116421afa85ee25e99b4c34fb  29c35fc91fc13fb5073c8f30505d860d
# 26180  12a95a3c06dbaec84bcfb0e2da5d228a  1e101e0daffaddce8159d25a8e53f2b2
# 30328  c1d4211b3dae76144deccd6c74144a88  684cb238dc5b5d6366244e0e0776b450
# 43338  d69e5d356402adc8cf17e08b5033acfb  68d081753ad4fe22fc4d410a9eb1ca01
# 44516  d77031d6a3c8a52f019764e68f211c69  0bf35cac6cc7327065da879e2d90fae8
# 54770  7002a78c79c519ac54022d4f8a65e6e8  d5de688c321096d15508faae67a27051
# 69806  2eecb0d85f281280f79fa00f9cec1a95  a3d3c38e58b9d2dfb9207cab690b6310
# 71308  51eb2eebd5d76a24625b31c33dd41449  07a2a7e0f63fd8cb757ed77d4245623c
# 76650  88083e8f64d95b932164187484d90212  f67cd1a215aae2a1074638bbd35a223a
# ...

# %%
#Excluir colunas que nao vamos utilizar
columns_drop = ['order_approved_at', 
 'order_delivered_carrier_date', 
 'product_name_lenght', 
 'product_description_lenght', 
 'product_photos_qty',
 'product_weight_g',               
 'product_length_cm',             
 'product_height_cm',
 'product_width_cm',
 'seller_zip_code_prefix',
 'customer_zip_code_prefix',
 'customer_unique_id']
df_vendas_olist = df_vendas_olist.drop(columns_drop, axis=1)
df_vendas_olist
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %%
#Verificar a base depois da exclusao das colunas
df_vendas_olist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  object
#  1   customer_id                    112650 non-null  object
#  2   order_status                   112650 non-null  object
#  3   order_purchase_timestamp       112650 non-null  object
#  4   order_delivered_customer_date  110196 non-null  object
#  5   order_estimated_delivery_date  112650 non-null  object
#  6   order_item_id                  112650 non-null  int64
#  7   product_id                     112650 non-null  object
#  8   seller_id                      112650 non-null  object
#  9   shipping_limit_date            112650 non-null  object
#  10  price                          112650 non-null  float64
#  11  freight_value                  112650 non-null  float64
# ...

# %%
#Filtrar a base por status de pedido
df_vendas_olist['order_status'].unique()
# Out:
# array(['delivered', 'invoiced', 'shipped', 'processing', 'canceled',
#        'unavailable', 'approved'], dtype=object)

# %%
#Verificar quantidade de pedido por status
df_vendas_olist['order_status'].value_counts()
# Out:
# order_status
# delivered      110197
# shipped          1185
# canceled          542
# invoiced          359
# processing        357
# unavailable         7
# approved            3
# Name: count, dtype: int64

# %%
#Filtrar apenas pedidos com status de entregue
df_vendas_olist = df_vendas_olist.loc[df_vendas_olist['order_status'] == 'delivered']
df_vendas_olist
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %%
# Filtrando somente pedidos finalizados, percebemos que perdemos um número razoável de linhas, cerca de 3 mil.
# Agora, com nosso dataset filtrado, precisamos resetar o seu index:
df_vendas_olist = df_vendas_olist.reset_index(drop=True)
df_vendas_olist
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 110192  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 110193  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 110194  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 110195  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 110196  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %%
#Verificar nossa base apos o filtro
df_vendas_olist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110197 entries, 0 to 110196
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       110197 non-null  object
#  1   customer_id                    110197 non-null  object
#  2   order_status                   110197 non-null  object
#  3   order_purchase_timestamp       110197 non-null  object
#  4   order_delivered_customer_date  110189 non-null  object
#  5   order_estimated_delivery_date  110197 non-null  object
#  6   order_item_id                  110197 non-null  int64
#  7   product_id                     110197 non-null  object
#  8   seller_id                      110197 non-null  object
#  9   shipping_limit_date            110197 non-null  object
#  10  price                          110197 non-null  float64
#  11  freight_value                  110197 non-null  float64
# ...

# %%
# Vamos transformar nossas colunas de data (que estão como string) em data: 
df_vendas_olist['order_purchase_timestamp'] = pd.to_datetime(df_vendas_olist['order_purchase_timestamp'])
df_vendas_olist['order_delivered_customer_date'] = pd.to_datetime(df_vendas_olist['order_delivered_customer_date'])

# Agora sim, vamos criar uma coluna de data e de mês!
df_vendas_olist['reference_date'] = df_vendas_olist['order_purchase_timestamp'].dt.date
df_vendas_olist['reference_month'] = df_vendas_olist['order_purchase_timestamp'].dt.strftime('%Y-%m-01')
df_vendas_olist['reference_month'] = pd.to_datetime(df_vendas_olist['reference_month'])
df_vendas_olist
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 110192  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 110193  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 110194  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 110195  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 110196  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %%
#Verificar a base de dados
df_vendas_olist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110197 entries, 0 to 110196
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       110197 non-null  object
#  1   customer_id                    110197 non-null  object
#  2   order_status                   110197 non-null  object
#  3   order_purchase_timestamp       110197 non-null  datetime64[ns]
#  4   order_delivered_customer_date  110189 non-null  datetime64[ns]
#  5   order_estimated_delivery_date  110197 non-null  object
#  6   order_item_id                  110197 non-null  int64
#  7   product_id                     110197 non-null  object
#  8   seller_id                      110197 non-null  object
#  9   shipping_limit_date            110197 non-null  object
#  10  price                          110197 non-null  float64
#  11  freight_value                  110197 non-null  float64
# ...

# %% [markdown]
# - Verificar e Tratar Nulos

# %%
# Contando o total de valores nulos em cada coluna
print(df_vendas_olist.isnull().sum())
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_delivered_customer_date       8
# order_estimated_delivery_date       0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# customer_city                       0
# customer_state                      0
# product_category_name            1537
# seller_city                         0
# seller_state                        0
# reference_date                      0
# reference_month                     0
# dtype: int64

# %%
# Substituindo valores nulos pela string 'diversos' na coluna 'product_category_name'
df_vendas_olist.loc[df_vendas_olist['product_category_name'].isnull(), 'product_category_name'] = 'diversos'

# Verificando o DataFrame após a substituição
print(df_vendas_olist['product_category_name'].isnull().sum())
# Out:
# 0

# %%
# Substituindo os valores nulos na coluna 'order_delivered_customer_date'
df_vendas_olist.loc[df_vendas_olist['order_delivered_customer_date'].isnull(), 'order_delivered_customer_date'] = df_vendas_olist['order_estimated_delivery_date']

# Verificando o DataFrame após a substituição
print(df_vendas_olist['order_delivered_customer_date'].isnull().sum())
# Out:
# 0

# %%
# Contando o total de valores nulos em cada coluna apos limpeza
print(df_vendas_olist.isnull().sum())
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# customer_city                    0
# customer_state                   0
# product_category_name            0
# seller_city                      0
# seller_state                     0
# reference_date                   0
# reference_month                  0
# dtype: int64

# %% [markdown]
# - Exportar base de dados

# %%
# Exportando a base final
df_vendas_olist.to_csv('base_vendas_s14_olist.csv', index=False)

# %% [markdown]
# ## **Análises**

# %% [markdown]
# ### 1. Qual é o valor médio das compras desses clientes? E qual o valor médio pago em frete?

# %%
# Aqui estamos buscando uma estatística descritiva, podemos utilizar a nossa função describe() para trazer essas informações
df_vendas_olist.describe().T
# Out:
#                                   count                           mean  \
# order_purchase_timestamp         110197  2018-01-02 02:49:51.928346368
# order_delivered_customer_date    110197  2018-01-14 14:11:04.916785408
# order_item_id                  110197.0                       1.198181
# price                          110197.0                     119.980563
# freight_value                  110197.0                      19.948598
# reference_month                  110197  2017-12-17 22:05:07.413087488
#
#                                                min                  25%  \
# order_purchase_timestamp       2016-09-15 12:16:38  2017-09-15 06:32:42
# order_delivered_customer_date  2016-10-11 13:46:32  2017-09-26 20:15:59
# order_item_id                                  1.0                  1.0
# price                                         0.85                 39.9
# freight_value                                  0.0                13.08
# ...

# %%
# Calculando a média de preço
media_preco = df_vendas_olist['price'].mean()

# Arredondando o resultado para 2 casas decimais
media_preco_arredondada = round(media_preco, 2)

print(f"Média de preço das compras: {media_preco_arredondada}")
# Out:
# Média de preço das compras: 119.98

# %% [markdown]
# - O valor médio das compras dos cliente presentes na base é de: R$ 119.98

# %%
# Calculando a média de preço
media_preco = df_vendas_olist['freight_value'].mean()

# Arredondando o resultado para 2 casas decimais
media_preco_arredondada = round(media_preco, 2)

print(f"Média de preço do frete: {media_preco_arredondada}")
# Out:
# Média de preço do frete: 19.95

# %% [markdown]
# - O valor médio de preço do frete presentes na base é de: R$ 19.95

# %% [markdown]
# ### 2. O número de vendas varia de acordo com a época do ano?

# %%
#Tabela de Sazonalidade ao londo dos anos
df_sazonalidade = df_vendas_olist.groupby('reference_month').agg({'order_id': 'nunique'})
df_sazonalidade.sort_values(by='order_id', ascending=False)
# Out:
#                  order_id
# reference_month
# 2017-11-01           7289
# 2018-01-01           7069
# 2018-03-01           7003
# 2018-04-01           6798
# 2018-05-01           6749
# 2018-02-01           6555
# 2018-08-01           6351
# 2018-07-01           6159
# 2018-06-01           6099
# 2017-12-01           5513
# 2017-10-01           4478
# 2017-08-01           4193
# 2017-09-01           4150
# 2017-07-01           3872
# 2017-05-01           3546
# 2017-06-01           3135
# 2017-03-01           2546
# 2017-04-01           2303
# 2017-02-01           1653
# 2017-01-01            750
# 2016-10-01            265
# 2016-09-01              1
# 2016-12-01              1

# %%
#Gráficos de linha analise ao longo dos anos
plt.figure(figsize=(15,5))
sns.lineplot(data=df_sazonalidade.reset_index().sort_values("reference_month"), x="reference_month", y="order_id")
plt.xticks(rotation=45);

# %% [markdown]
# - Não parece existir um padrão de vendas ao longo dos anos e a tendência de crescimento da curva, pode dificultar a visualização de uma sazonalidade mensal.

# %% [markdown]
# Vamos analizar as vendas por dia.

# %%
# Sazonalidade por dia
date_sazonality = df_vendas_olist.groupby('reference_date').agg({'order_id': 'nunique'}).reset_index().sort_values("reference_date")

# %%
#Gráficos de linha analise por dia
plt.figure(figsize=(15,5))
sns.lineplot(data=date_sazonality, 
             x="reference_date", y="order_id")

# Limitar o número de ticks no eixo x
plt.xticks(date_sazonality['reference_date'][::10], rotation=45)  # Altere o valor de '5' para outro intervalo desejado
plt.show()

# %%
#Gráficos de linha analise por dia de JAN a MAR de 2018

# Convertendo as datas para objetos datetime.date
data_inicio = pd.to_datetime("2018-01-01").date()
data_fim = pd.to_datetime("2018-03-01").date()

# Filtrando os dados e criando o gráfico de linha
plt.figure(figsize=(15, 5))
sns.lineplot(data=date_sazonality[(date_sazonality.reference_date >= data_inicio) & (date_sazonality.reference_date <= data_fim)], 
             x="reference_date", y="order_id")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Quais os dias com mais e menos vendas?

# %%
# Converta a coluna 'reference_date' para o formato datetime
df_vendas_olist["reference_date"] = pd.to_datetime(df_vendas_olist["reference_date"])

# Calcule o dia da semana (número de 0 a 6, onde 0 = segunda-feira)
df_vendas_olist["day_of_week"] = df_vendas_olist["reference_date"].dt.dayofweek

# Obtenha o nome do dia da semana
df_vendas_olist["day_name"] = df_vendas_olist["reference_date"].dt.day_name()

# %%
#Tabela 
df_vendas_olist[(df_vendas_olist.reference_date >= "2018-01-01") & (df_vendas_olist.reference_date <= "2018-03-01")].sort_values("reference_date")[["reference_date", "day_of_week", "day_name"]].drop_duplicates()
# Out:
#        reference_date  day_of_week   day_name
# 5185       2018-01-01            0     Monday
# 31160      2018-01-02            1    Tuesday
# 75012      2018-01-03            2  Wednesday
# 14263      2018-01-04            3   Thursday
# 63601      2018-01-05            4     Friday
# 103549     2018-01-06            5   Saturday
# 18814      2018-01-07            6     Sunday
# 67397      2018-01-08            0     Monday
# 78951      2018-01-09            1    Tuesday
# 2146       2018-01-10            2  Wednesday
# 33323      2018-01-11            3   Thursday
# 4759       2018-01-12            4     Friday
# 59442      2018-01-13            5   Saturday
# 95870      2018-01-14            6     Sunday
# 60073      2018-01-15            0     Monday
# 73297      2018-01-16            1    Tuesday
# 109837     2018-01-17            2  Wednesday
# 2883       2018-01-18            3   Thursday
# 88986      2018-01-19            4     Friday
# ...

# %% [markdown]
# Vamos analisar os dados por meses.

# %%
# Calculando os meses
df_vendas_olist["month"] = df_vendas_olist["reference_month"].apply(lambda x: pd.to_datetime(x).month)

month_sazonality = df_vendas_olist.groupby("month").agg({"order_id": "nunique"})

# %%
#Gráficos de linhas analise por mês
plt.figure(figsize=(15,5))
sns.lineplot(data=month_sazonality, 
             x="month", y="order_id")
plt.xlabel("Mês")
plt.ylabel("Quantidade de Vendas")
# Out:
# Text(0, 0.5, 'Quantidade de Vendas')

# %%
# Calculando os meses
df_vendas_olist["year"] = df_vendas_olist["reference_date"].dt.year
year_month_sazonality = df_vendas_olist.groupby(["year", "month"]).agg({"order_id": "nunique"})

#Gráficos de linhas analise mês/ano
plt.figure(figsize=(15,5))
sns.lineplot(data=year_month_sazonality, 
             x="month", y="order_id", hue="year")
# Out:
# <Axes: xlabel='month', ylabel='order_id'>

# %%
# Data minima presente na base e data maxima. 
print(df_vendas_olist.reference_date.min())
print(df_vendas_olist.reference_date.max())
# Out:
# 2016-09-15 00:00:00
# 2018-08-29 00:00:00

# %% [markdown]
# - Não é possível identificar uma tendência de aumento ou diminuição nas vendas da base de dados, uma vez que os anos de 2016 e 2018 não estão completos. Portanto, não podemos analisar quais meses, semanas ou dias apresentam tendência de crescimento.

# %% [markdown]
# ### 3. O tempo limite de entrega das compras está sendo respeitado?

# %%
#Transformando as colunas em datetima
df_vendas_olist['order_delivered_customer_date'] = pd.to_datetime(df_vendas_olist['order_delivered_customer_date'])
df_vendas_olist['order_delivered_date'] = df_vendas_olist['order_delivered_customer_date'].dt.date
df_vendas_olist['shipping_limit_dt'] = pd.to_datetime(df_vendas_olist['shipping_limit_date']).dt.date

# Classificando
df_vendas_olist.loc[df_vendas_olist['order_delivered_date'] > df_vendas_olist['shipping_limit_dt'], 'status_entrega'] = 'ATRASADO'
df_vendas_olist.loc[df_vendas_olist['order_delivered_date'] < df_vendas_olist['shipping_limit_dt'], 'status_entrega'] = 'ADIANTADO'
df_vendas_olist.loc[df_vendas_olist['order_delivered_date'] == df_vendas_olist['shipping_limit_dt'], 'status_entrega'] = 'DENTRO DO ESPERADO'
df_vendas_olist
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 110192  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 110193  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 110194  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 110195  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 110196  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %%
# Porcentagem de pedidos com base na classificacao
df_vendas_olist["status_entrega"].value_counts(normalize=True)*100
# Out:
# status_entrega
# ATRASADO              72.760601
# ADIANTADO             18.322640
# DENTRO DO ESPERADO     8.916758
# Name: proportion, dtype: float64

# %% [markdown]
# - Cerca de 72,76% dos pedidos sao entregues com atraso e cerca de 18.32% sao entregues adiantados, e somente 8,9% dos pedidos sao entregues dentro do prazo.

# %% [markdown]
# ### 4. Indique quais os três estados que possuem a maioria dos clientes na base de dados e quais três estados abrigam a maior quantidade de vendedores?

# %%
# Contar quantos estados únicos existem na coluna 'customer_state'
num_estados_clientes = df_vendas_olist['customer_state'].nunique()
print(f"Quantidade de estados (clientes): {num_estados_clientes}")

# Contar quantos estados únicos existem na coluna 'seller_state'
num_estados_vendedores = df_vendas_olist['seller_state'].nunique()
print(f"Quantidade de estados (vendedores): {num_estados_vendedores}")
# Out:
# Quantidade de estados (clientes): 27
# Quantidade de estados (vendedores): 22

# %%
# Quantidade de clientes por estado
df_vendas_olist['customer_state'].value_counts()
# Out:
# customer_state
# SP    46448
# RJ    14143
# MG    12916
# RS     6134
# PR     5649
# SC     4097
# BA     3683
# DF     2355
# GO     2277
# ES     2225
# PE     1746
# CE     1426
# PA     1054
# MT     1037
# MS      811
# MA      800
# PB      586
# PI      523
# RN      521
# AL      427
# SE      375
# TO      310
# RO      273
# AM      163
# AC       91
# AP       81
# RR       46
# Name: count, dtype: int64

# %% [markdown]
# - Os três estados com a maior quantidade de clientes são, respectivamente:
# São Paulo, Rio de Janeiro e Minas Gerais

# %%
# Quantidade de vendedores por estado
df_vendas_olist['seller_state'].value_counts()
# Out:
# seller_state
# SP    78604
# MG     8603
# PR     8487
# RJ     4685
# SC     4000
# RS     2169
# DF      883
# BA      624
# GO      508
# PE      445
# MA      402
# ES      364
# MT      144
# CE       90
# RN       56
# MS       50
# PB       37
# RO       14
# PI       11
# SE       10
# PA        8
# AM        3
# Name: count, dtype: int64

# %% [markdown]
# - E os três estados com a maior quantidade de vendedores são, respectivamente:
# São Paulo, Minas Gerais e Paraná

# %% [markdown]
# ### 5. Quais são as 10 categorias mais vendidas? E as 10 menos vendidas?

# %%
#Quandidade de categorias presentes na base
num_categorias = df_vendas_olist['product_category_name'].nunique()

# Exibindo o resultado
print(f"Quantidade de categorias presentes na base: {num_categorias}")
# Out:
# Quantidade de categorias presentes na base: 74

# %% [markdown]
# - Temos 74 categorias diferentes na base de dados

# %%
# Agrupando os produtos por categoria e contando o número de itens vendidos
produtos_por_categoria = df_vendas_olist.groupby('product_category_name')['order_item_id'].count().reset_index()
produtos_por_categoria.columns = ['Categoria', 'Quantidade Vendida']

# Ordenando os produtos pela quantidade vendida
produtos_por_categoria = produtos_por_categoria.sort_values(by='Quantidade Vendida', ascending=False)

# Exibindo as 10 principais categorias
print(produtos_por_categoria.head(10))
# Out:
#                  Categoria  Quantidade Vendida
# 13         cama_mesa_banho               10953
# 11            beleza_saude                9465
# 33           esporte_lazer                8431
# 55        moveis_decoracao                8160
# 45  informatica_acessorios                7644
# 73   utilidades_domesticas                6795
# 67      relogios_presentes                5859
# 71               telefonia                4430
# 41      ferramentas_jardim                4268
# 8               automotivo                4140

# %% [markdown]
# - As 10 categorias mais vendidas na base de dados são:
# Cama, Mesa e Banho, Beleza e Saúde, Esporte e Lazer, Móveis e Decoração, Informática e Acessórios, Utilidades Domésticas, Relógios e Presentes, Telefonia, Ferramentas e Jardim e, por último, Automotivo.

# %%
# Agrupando os produtos por categoria e contando o número de itens vendidos
produtos_por_categoria = df_vendas_olist.groupby('product_category_name')['order_item_id'].count().reset_index()
produtos_por_categoria.columns = ['Categoria', 'Quantidade Vendida']

# Ordenando os produtos pela quantidade vendida
produtos_por_categoria = produtos_por_categoria.sort_values(by='Quantidade Vendida', ascending=True)

# Exibindo as 10 principais categorias
print(produtos_por_categoria.head(10))
# Out:
#                                         Categoria  Quantidade Vendida
# 68                             seguros_e_servicos                   2
# 38                  fashion_roupa_infanto_juvenil                   7
# 61                                       pc_gamer                   8
# 17                              cds_dvds_musicais                  14
# 66  portateis_cozinha_e_preparadores_de_alimentos                  14
# 47                                     la_cuisine                  14
# 4                              artes_e_artesanato                  24
# 36                                fashion_esporte                  29
# 15                                casa_conforto_2                  30
# 42                                         flores                  33

# %% [markdown]
# - As 10 categorias menos vendidas na base de dados são:
# Seguros e Serviços, Roupas Infanto-Juvenis, PC Gamer, CDs e DVDs Musicais, Portáteis de Cozinha e Preparadores de Alimentos, La Cuisine, Artes e Artesanato, Esporte e Moda, Casa Conforto 2 e, por último, Flores.

# %% [markdown]
# ### 6. Qual a média de valor gasto pelos clientes por estado? Qual o estado que possue a média mais alta?

# %%
# Verificar a média
media_por_estado = df_vendas_olist.groupby('customer_state')['price'].mean().reset_index()
media_por_estado.columns = ['Estado', 'Média de Valor Gasto']

# Ordenando os produtos pelo maior valor
media_por_estado = media_por_estado.sort_values(by='Média de Valor Gasto', ascending=False)

#Exibir os estados
print('Média de Valor Gasto por Cliente em cada Estado')
print(media_por_estado)
# Out:
# Média de Valor Gasto por Cliente em cada Estado
#    Estado  Média de Valor Gasto
# 14     PB            192.127679
# 1      AL            184.673817
# 0      AC            175.065604
# 20     RO            167.336117
# 13     PA            165.531869
# 3      AP            165.121111
# 16     PI            161.990440
# 19     RN            157.592438
# 26     TO            156.137129
# 5      CE            154.107560
# 21     RR            153.423261
# 24     SE            150.864507
# 12     MT            146.761446
# 9      MA            146.261725
# 15     PE            144.266604
# 11     MS            142.330419
# 2      AM            135.925399
# 4      BA            134.016872
# 6      DF            125.901660
# 18     RJ            124.418520
# 8      GO            124.214625
# 23     SC            123.752045
# 7      ES            120.738629
# 10     MG            120.198345
# 22     RS            118.829063
# 17     PR            117.908216
# ...

# %% [markdown]
# - O estado com o maior valor médio de gasto por cliente é a **PB** (Paraíba), com aproximadamente RS 192,13.

# %% [markdown]
# ### 7. Quais categorias de produtos têm um valor mais elevado de vendas? Ou seja, qual categoria vende mais?

# %%
# Configurando a opção de visualização para não resumir a saída
pd.set_option('display.max_rows', None)  # Isso exibe todas as linhas sem truncamento/sem resumir (...)

# Agrupando os produtos por categoria e contando o preço total por categoria
preco_por_categoria = df_vendas_olist.groupby('product_category_name')['price'].sum().reset_index()
preco_por_categoria.columns = ['Categoria', 'Preço Total']

# Ordenando os produtos pelo preço total (decrescente)
preco_por_categoria = preco_por_categoria.sort_values(by='Preço Total', ascending=False)

# Exibindo o total de vendas por categoria
print('Total de Vendas por Categoria:')
print(preco_por_categoria)
# Out:
# Total de Vendas por Categoria:
#                                          Categoria  Preço Total
# 11                                    beleza_saude   1233131.72
# 67                              relogios_presentes   1166176.98
# 13                                 cama_mesa_banho   1023434.76
# 33                                   esporte_lazer    954852.55
# 45                          informatica_acessorios    888724.61
# 55                                moveis_decoracao    711927.69
# 73                           utilidades_domesticas    615628.69
# 26                                      cool_stuff    610204.10
# 8                                       automotivo    578966.65
# 12                                      brinquedos    471286.48
# 41                              ferramentas_jardim    470495.28
# 9                                            bebes    400421.84
# 63                                      perfumaria    390144.65
# ...

# %% [markdown]
# - Beleza e Saúde, lidera o ranking de vendas com um total de RS 1.233.131,72. Seguida pela categoria de Relógios e Presentes que esta em segundo lugar, com um total de RS 1.166.176,98 em vendas. Ja a categoria de Cama, Mesa e Banho, ocupa a terceira posição com RS 1.023.434,76 em vendas.

# %% [markdown]
# ### 8. Qual a média de venda por estado? Qual o estado possui a média mais alta?

# %%
# Verificar a média
media_por_estado = df_vendas_olist.groupby('seller_state')['price'].mean().reset_index()
media_por_estado.columns = ['Estado', 'Média de Venda']

# Ordenando os produtos pelo maior valor
media_por_estado = media_por_estado.sort_values(by='Média de Venda', ascending=False)

#Exibir os estados
print('Média de Venda por Estado')
print(media_por_estado)
# Out:
# Média de Venda por Estado
#    Estado  Média de Venda
# 1      BA      445.393446
# 11     PB      443.121622
# 0      AM      392.333333
# 17     RO      340.157143
# 2      CE      216.864889
# 13     PI      216.636364
# 12     PE      204.863258
# 16     RN      178.439286
# 15     RJ      175.157223
# 18     RS      172.158635
# 8      MS      171.033800
# 20     SE      160.620000
# 10     PA      154.750000
# 19     SC      153.397913
# 14     PR      145.174619
# 4      ES      128.960549
# 5      GO      127.572028
# 9      MT      118.109861
# 7      MG      113.665734
# 21     SP      108.257995
# 3      DF      107.406920
# 6      MA       89.795970

# %% [markdown]
# - O estado com a maior media de venda presente na base de dados e o estado da **BA** (Bahia) com aproximadamente RS 445,39.

# %% [markdown]
# ## **Visualizações**

# %% [markdown]
# ### - Média do Valor de Compras por Cliente e do Frete

# %%
# Calculando as médias
media_preco_compra = df_vendas_olist['price'].mean()
media_preco_frete = df_vendas_olist['freight_value'].mean()

# Arredondando para 2 casas decimais
media_preco_compra_arredondada = round(media_preco_compra, 2)
media_preco_frete_arredondada = round(media_preco_frete, 2)

# Criando os dados para o gráfico
labels = ['Preço Médio das Compras', 'Preço Médio do Frete']
valores = [media_preco_compra_arredondada, media_preco_frete_arredondada]

# Configurando o gráfico de barras
plt.figure(figsize=(8, 5))
sns.barplot(x=labels, y=valores, hue=labels, palette='viridis', legend=False)

# Adicionando rótulos de valor nas barras
for i, v in enumerate(valores):
    plt.text(i, v + 1, f'{v:.2f}', ha='center', va='bottom', fontsize=12)

# Título e rótulos
plt.title('Comparação entre Preço Médio das Compras e do Frete', fontsize=16)
plt.ylabel('Valor em R$', fontsize=12)
plt.xlabel('Categorias', fontsize=12)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# A **média de preço das compras** é de RS 119,98, o que indica que, em média, cada cliente gasta cerca de RS 120,00 em suas compras na plataforma. Já a **média de preço do frete** é de RS 19,95, mostrando que o custo médio de envio por pedido é aproximadamente RS 20,00. Esses valores ajudam a entender o comportamento de compra dos clientes e o impacto dos custos de frete no valor final.

# %% [markdown]
# ### - Sazonalidade de Vendas

# %%
# Calculando os meses e extraindo o ano e o mês
df_vendas_olist["year"] = df_vendas_olist["reference_date"].dt.year
df_vendas_olist["month"] = df_vendas_olist["reference_date"].dt.month
year_month_sazonality = df_vendas_olist.groupby(["year", "month"]).agg({"order_id": "nunique"}).reset_index()

# Gráfico de linhas para análise de pedidos por mês/ano
plt.figure(figsize=(15, 6))
sns.lineplot(data=year_month_sazonality, x="month", y="order_id", hue="year", marker='o', palette='viridis')

# Adicionando título e rótulos aos eixos
plt.title('Sazonalidade dos Pedidos por Mês e Ano', fontsize=16)
plt.xlabel('Mês', fontsize=12)
plt.ylabel('Número de Pedidos', fontsize=12)

# Ajustando os ticks dos meses para representar os meses do ano
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# Exibindo a legenda
plt.legend(title='Ano')

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
# Agrupando os dados pelo ano e contando o número de pedidos
pedidos_por_ano = df_vendas_olist.groupby("year")["order_id"].nunique().reset_index()

# Renomeando as colunas para facilitar a visualização
pedidos_por_ano.columns = ["Ano", "Total de Pedidos"]

# Plotando o gráfico de barras
plt.figure(figsize=(10, 6))
sns.barplot(x="Ano", y="Total de Pedidos", data=pedidos_por_ano, hue='Ano', palette='viridis', legend=False)

# Adicionando rótulos às barras
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():,.0f}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='baseline', fontsize=10, color='black', 
                       xytext=(0, 5), textcoords='offset points')

# Adicionando título e rótulos aos eixos
plt.title('Total de Pedidos por Ano', fontsize=16)
plt.xlabel('Ano', fontsize=12)
plt.ylabel('Total de Pedidos', fontsize=12)

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# Analise de vendas por semana

# %%
# Convert the "reference_date" column to datetime
df_vendas_olist["reference_date"] = pd.to_datetime(df_vendas_olist["reference_date"], errors="coerce")

# Calculando o dia da semana (0 = segunda-feira, 6 = domingo)
df_vendas_olist["day_of_week"] = df_vendas_olist["reference_date"].dt.dayofweek

# Criando um gráfico de barras para visualizar as vendas por dia da semana
plt.figure(figsize=(10, 6))
sns.countplot(data=df_vendas_olist, x="day_of_week", palette="viridis", hue="day_of_week", legend=False)
plt.xlabel("Dia da Semana")
plt.ylabel("Quantidade de Vendas")
plt.title("Vendas por Dia da Semana")
plt.xticks(range(7), ["Seg", "Ter", "Qua", "Qui", "Sex", "Sáb", "Dom"])
plt.show()

# %% [markdown]
# - Não é possível identificar uma tendência de aumento ou diminuição nas vendas da base de dados, uma vez que os anos de 2016 e 2018 não estão completos. Portanto, não podemos analisar quais meses, semanas ou dias apresentam tendência de crescimento.

# %% [markdown]
# ### - Prazo de Entrega

# %%
# Contagem de porcentagens por status de entrega
status_porcentagem = df_vendas_olist["status_entrega"].value_counts(normalize=True) * 100

# Plotando o gráfico de pizza
plt.figure(figsize=(8, 8))
plt.pie(status_porcentagem, labels=status_porcentagem.index, autopct='%1.1f%%', colors=sns.color_palette('viridis'), startangle=140)
plt.title('Porcentagem de Pedidos por Status de Entrega', fontsize=16)
plt.show()

# %% [markdown]
# O Gráfico de Pizza indica que a maior parte dos pedidos está sendo entregue com atraso, o que pode impactar negativamente a satisfação dos clientes e a reputação da empresa. Enquanto algumas entregas são feitas antes do prazo, a baixa porcentagem de entregas no prazo esperado indica uma área importante para melhoria na logística e planejamento de entregas.

# %% [markdown]
# ### - Clientes e Vendedores por Estado

# %%
# Contando a quantidade de clientes por estado
clientes_por_estado = df_vendas_olist['customer_state'].value_counts()

# Selecionando os três estados com maior quantidade de clientes
top3_estados = clientes_por_estado.head(3)

# Plotando o gráfico de barras
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=top3_estados.index, y=top3_estados.values, hue=top3_estados.index, palette='viridis', legend=False)

# Adicionando rótulos às barras
for p in ax.patches:
    ax.annotate(f'{p.get_height():,}', 
                (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.title('Top 3 Estados com Maior Quantidade de Clientes', fontsize=16)
plt.xlabel('Estado', fontsize=12)
plt.ylabel('Quantidade de Clientes', fontsize=12)
plt.show()

# %% [markdown]
# **Estados com Mais Clientes**:
#
# São Paulo (SP): 46,448 clientes.
#
# Rio de Janeiro (RJ): 14,143 clientes.
#
# Minas Gerais (MG): 12,916 clientes.
#
# São Paulo é o estado com o maior número de clientes, seguido por Rio de Janeiro e Minas Gerais. Esses estados são, provavelmente, os maiores centros de mercado para sua base de dados, o que pode indicar uma alta demanda ou uma maior presença da empresa nessas regiões.

# %%
# Contando a quantidade de vendedores por estado
clientes_por_estado = df_vendas_olist['seller_state'].value_counts()

# Selecionando os três estados com maior quantidade de vendedores
top3_estados = clientes_por_estado.head(3)

# Plotando o gráfico de barras
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=top3_estados.index, y=top3_estados.values, hue=top3_estados.index, palette='viridis', legend=False)

# Adicionando rótulos às barras
for p in ax.patches:
    ax.annotate(f'{p.get_height():,}', 
                (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.title('Top 3 Estados com Maior Quantidade de Vendedores', fontsize=16)
plt.xlabel('Estado', fontsize=12)
plt.ylabel('Quantidade de Vendedores', fontsize=12)
plt.show()

# %% [markdown]
# **Estados com Mais Vendedores**:
#
# São Paulo (SP): 78,604 vendedores.
#
# Minas Gerais (MG): 8,603 vendedores.
#
# Paraná (PR): 8,487 vendedores.
#
# São Paulo (SP) tem um número muito elevado de vendedores comparado aos outros estados. Isso sugere que São Paulo é um grande centro de atividades comerciais, com uma alta densidade de vendedores. Minas Gerais (MG) e Paraná (PR) também têm um número significativo de vendedores, mas bem menor em comparação com São Paulo.

# %% [markdown]
# ### - Categorias Mais Vendidas

# %%
# Ordenando os dados de produtos_por_categoria de forma decrescente
produtos_por_categoria = produtos_por_categoria.sort_values(by='Quantidade Vendida', ascending=False)

# Plotando a distribuição por categoria (gráfico de barras)
plt.figure(figsize=(15, 6))
ax = sns.barplot(x='Quantidade Vendida', y='Categoria', data=produtos_por_categoria.head(10), hue='Categoria', palette='viridis')

# Adicionando rótulos às barras
for p in ax.patches:
    ax.annotate(f'{p.get_width():,.0f}', 
                (p.get_width() + 500, p.get_y() + p.get_height() / 2), 
                ha='left', va='center', 
                fontsize=10, color='black', 
                xytext=(10, 0), 
                textcoords='offset points')

plt.title('Top 10 Categorias Mais Vendidas', fontsize=16)
plt.xlabel('Quantidade Vendida', fontsize=12)
plt.ylabel('Categoria', fontsize=12)
plt.show()

# %% [markdown]
# O Gráfico de Barras Inclinadas indica as 10 principais categorias e suas respectivas quantidades vendidas:
#
# Cama, Mesa e Banho (10.953 unidades vendidas): Essa categoria lidera em número de vendas, o que indica que produtos de cama, mesa e banho têm uma alta demanda.
#
# Beleza e Saúde (9.465 unidades vendidas): A categoria de beleza e saúde está em segundo lugar, o que reflete a busca contínua por produtos de cuidados pessoais, como cosméticos, itens de higiene e produtos de bem-estar.
#
# Esporte e Lazer (8.431 unidades vendidas): Essa categoria também apresenta um volume significativo de vendas, indicando que as pessoas estão investindo em produtos relacionados a atividades físicas e lazer, o que pode estar relacionado ao aumento da conscientização sobre saúde e bem-estar.
#
# Móveis e Decoração (8.160 unidades vendidas): Produtos de móveis e decoração ocupam a quarta posição, sugerindo que os consumidores estão preocupados em manter suas casas bem decoradas e funcionais.
#
# Informática e Acessórios (7.644 unidades vendidas): A presença dessa categoria reflete a demanda por produtos eletrônicos e acessórios, como periféricos de computador e dispositivos relacionados à tecnologia.
#
# Utilidades Domésticas (6.795 unidades vendidas): A categoria de utilidades domésticas é importante para o funcionamento diário das residências, e isso explica o volume de vendas relativamente alto.
#
# Relógios e Presentes (5.859 unidades vendidas): Relógios e presentes estão no sétimo lugar, o que sugere que esses itens são populares, especialmente para compras sazonais ou para ocasiões especiais.
#
# Telefonia (4.430 unidades vendidas): A demanda por itens de telefonia, como celulares e acessórios, também é relevante, mas o volume de vendas é um pouco menor em comparação com as categorias acima.
#
# Ferramentas e Jardim (4.268 unidades vendidas): Produtos relacionados a ferramentas e jardinagem são comprados com frequência, possivelmente por pessoas que se dedicam à manutenção de suas casas e jardins.
#
# Automotivo (4.140 unidades vendidas): A categoria automotiva reflete a compra de acessórios e peças para carros, indicando que os consumidores investem na manutenção e personalização de seus veículos.

# %% [markdown]
# ### - Média Estadual de Valor Gasto por Clientes

# %%
# Verificar a média
media_por_estado = df_vendas_olist.groupby('customer_state')['price'].mean().reset_index()
media_por_estado.columns = ['Estado', 'Média de Valor Gasto']

# Ordenando os estados pela maior média de valor gasto
media_por_estado = media_por_estado.sort_values(by='Média de Valor Gasto', ascending=False)

# Selecionando os cinco estados com a maior média de valor gasto
top5_estados = media_por_estado.head(5)

# Plotando o gráfico de barras
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='Estado', y='Média de Valor Gasto', data=top5_estados, hue='Média de Valor Gasto', palette='viridis', legend=False)

# Adicionando rótulos às barras
for p in ax.patches:
    ax.annotate(f'{p.get_height():,.2f}', 
                (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.title('Top 5 Estados com Maior Média de Valor Gasto por Cliente', fontsize=16)
plt.xlabel('Estado', fontsize=12)
plt.ylabel('Média de Valor Gasto (R$)', fontsize=12)
plt.show()

# %% [markdown]
# O Gráfico de Barras acima mostra a média de valor gasto por cliente em cinco estados. Vamos analisar cada estado:
#
# **Paraíba (PB)**
#
# Média de Valor Gasto: RS 192.13
# Os clientes da Paraíba têm o maior valor médio de gasto por cliente na sua base de dados. Isso pode indicar que, em média, os clientes desse estado estão comprando produtos mais caros ou comprando mais frequentemente.
#
# Alagoas (AL)
#
# Média de Valor Gasto: RS 184.67
# Alagoas é o segundo estado com a maior média de valor gasto por cliente. Assim como na Paraíba, isso sugere que os clientes desse estado também têm um comportamento de compra que resulta em valores mais altos.
#
# Acre (AC)
#
# Média de Valor Gasto: RS 175.07
# O Acre está em terceiro lugar. O valor gasto por cliente é um pouco menor que nos estados anteriores, mas ainda assim é significativo.
#
# Rondônia (RO)
#
# Média de Valor Gasto: RS 167.34
# Em Rondônia, a média de valor gasto por cliente é menor do que nos estados anteriores, mas ainda alta em comparação com a maioria dos outros estados.
#
# Pará (PA)
#
# Média de Valor Gasto: RS 165.53
# O Pará completa a lista dos cinco estados com maior média de valor gasto por cliente. O valor é ligeiramente menor do que em Rondônia, mas ainda bastante elevado.
#
# Considerando a média de gastos mais altos, você pode ajustar suas políticas de preços e ofertas específicas para esses estados para maximizar a receita e atender às preferências locais.

# %% [markdown]
# ### - Categoria mais Lucrativa

# %%
# Agrupando os produtos por categoria e somando o preço total por categoria
preco_por_categoria = df_vendas_olist.groupby('product_category_name')['price'].sum().reset_index()
preco_por_categoria.columns = ['Categoria', 'Preço Total']

# Ordenando as categorias pelo preço total (decrescente) e selecionando as 10 principais
preco_por_categoria = preco_por_categoria.sort_values(by='Preço Total', ascending=False).head(10)

# Plotando o gráfico de barras horizontais
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='Preço Total', y='Categoria', data=preco_por_categoria, hue='Preço Total', palette='viridis', legend=False)

# Adicionando rótulos às barras
for p in ax.patches:
    ax.annotate(f'R$ {p.get_width():,.2f}', 
                (p.get_width(), p.get_y() + p.get_height() / 2), 
                ha='left', va='center', 
                fontsize=10, color='black', 
                xytext=(5, 0), 
                textcoords='offset points')

# Título e rótulos dos eixos
plt.title('Top 10 Categorias com Maior Lucro', fontsize=16)
plt.xlabel('Preço Total (R$)', fontsize=12)
plt.ylabel('Categoria', fontsize=12)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# As 10 categorias com maior valor de vendas são lideradas por:
#  "beleza_saude" com RS 1.233.131,72, seguida por
#  "relogios_presentes" com RS 1.166.176,98 e
#  "cama_mesa_banho" com RS 1.023.434,76.
#
# Outras categorias de destaque incluem:
# "esporte_lazer", "informatica_acessorios" e "moveis_decoracao", com vendas variando entre RS 888.724,61 e RS 711.927,69.
# As categorias "utilidades_domesticas", "cool_stuff" e "automotivo" também apresentaram volumes consideráveis, com vendas superiores a RS 570.000,00, seguidas por "brinquedos" com RS 471.286,48.

# %% [markdown]
# ### - Média de Venda por Estado

# %%
# Verificar a média
media_por_estado = df_vendas_olist.groupby('seller_state')['price'].mean().reset_index()
media_por_estado.columns = ['Estado', 'Média de Venda']

# Ordenando os produtos pelo maior valor
media_por_estado = media_por_estado.sort_values(by='Média de Venda', ascending=False)

# Selecionando os cinco estados com a maior média de valor gasto
top5_estados = media_por_estado.head(5)

# Plotando o gráfico de barras
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='Estado', y='Média de Venda', data=top5_estados, hue='Média de Venda', palette='viridis', legend=False)

# Adicionando rótulos às barras
for p in ax.patches:
    ax.annotate(f'{p.get_height():,.2f}', 
                (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.title('Top 5 Estados com Maior Média de Vendas', fontsize=16)
plt.xlabel('Estado', fontsize=12)
plt.ylabel('Média de Venda (R$)', fontsize=12)
plt.show()

# %% [markdown]
# O Gráfico de Barras acima mostra a média de vendas em cinco estados:
#
# **Bahia (BA)**
#
# Média de Valor Gasto: RS 445.39
# A Bahia tem a maior média de vendas entre os estados listados. Isso indica que os vendedores na Bahia, em média, vendem mais do que os vendendores em outros estados da lista.
#
# Paraíba (PB)
#
# Média de Valor Gasto: RS 443.12
# A Paraíba está muito próxima da Bahia em termos de média de vendas. Isso sugere que os vendedores na Paraíba também vendem valores significativamente altos.
#
# Amazonas (AM)
#
# Média de Valor Gasto: RS 392.33
# O Amazonas tem a terceira maior média de vendas. Embora o valor seja menor do que na Bahia e na Paraíba, ainda é considerável.
#
# Rondônia (RO)
#
# Média de Valor Gasto: RS 340.16
# Em Rondônia, o valor médio de venda é menor em comparação com os três primeiros estados, mas ainda alto em relação a outros estados.
#
# Ceará (CE)
#
# Média de Valor Gasto: RS 216.86
# O Ceará apresenta a menor média de venda entre os estados listados, mas ainda assim, o valor é relativamente alto comparado a muitos outros estados fora desta lista.

# %% [markdown]
# ## **Conclusão**

# %% [markdown]
# Com base nas análises realizadas, é possível concluir o seguinte:
#
# 1. **Média do Valor de Compras e Frete**:
#    A média do valor das compras (RS 119,98) e do frete (RS 19,95) revela que o frete representa uma parcela significativa no total pago pelos clientes, cerca de 17% do valor médio da compra. Esse valor de frete pode influenciar diretamente as decisões de compra dos clientes, principalmente em regiões onde o preço final é mais sensível.
#
# 2. **Sazonalidade de Vendas**:
#    Devido à falta de dados completos para todos os meses e anos analisados, não é possível identificar claramente um padrão sazonal nas vendas. No entanto, essa informação sugere a necessidade de dados mais completos e consistentes para uma análise mais precisa, a fim de identificar oportunidades de otimização nas estratégias de vendas ao longo do ano.
#
# 3. **Prazo de Entrega**:
#    A alta taxa de entregas atrasadas, indicada pelo gráfico de pizza, é uma preocupação significativa para a empresa. Atrasos podem prejudicar a satisfação dos clientes, levando a uma percepção negativa da marca. Melhorias na logística e no planejamento de entregas são essenciais para reverter essa situação e aumentar a confiança dos consumidores.
#
# 4. **Distribuição de Clientes e Vendedores por Estado**:
#    A concentração de clientes e vendedores em São Paulo (SP), Rio de Janeiro (RJ) e Minas Gerais (MG) mostra a importância dessas regiões para o negócio. São Paulo se destaca como o principal mercado, com a maior quantidade tanto de clientes quanto de vendedores, sugerindo que a empresa tem uma forte presença nesses estados, que são os principais centros de comércio e consumo no Brasil.
#
# 5. **Categorias Mais Vendidas**:
#    As categorias mais vendidas, como "cama_mesa_banho", "beleza_saude", e "esporte_lazer", indicam que os produtos voltados para o lar, cuidados pessoais e lazer são os mais demandados. Isso pode fornecer insights para a empresa ajustar seu estoque e campanhas de marketing focadas nessas categorias de maior demanda.
#
# 6. **Média de Valor Gasto por Estado**:
#    Estados como Paraíba, Alagoas e Acre apresentam os maiores valores médios de gasto por cliente. Isso sugere que nesses estados há uma tendência de compra de produtos de maior valor, o que pode ser explorado com ofertas e estratégias de marketing específicas para esses locais, visando aumentar ainda mais o ticket médio.
#
# 7. **Categoria Mais Lucrativa**:
#    As categorias com maior valor de vendas, como "beleza_saude" e "relogios_presentes", revelam áreas de grande lucratividade. A empresa pode investir mais nessas categorias, tanto em termos de marketing quanto de melhoria no portfólio de produtos, para maximizar os lucros.
#
# 8. **Média de Venda por Estado**:
#    A Bahia e a Paraíba apresentam as maiores médias de vendas, destacando a força de mercado desses estados. Isso sugere que os vendedores nessas regiões têm um desempenho elevado, indicando uma oportunidade de expansão e fortalecimento da base de vendedores em outras regiões para aumentar o desempenho geral da empresa.
#
# Esses insights combinados podem guiar estratégias de crescimento, tanto em termos de otimização de processos logísticos quanto no foco em regiões e categorias de maior retorno financeiro.
